# %%
#!/usr/bin/env python3
# -*- coding: UTF-8 -*-

from backtrader.cerebro import OptReturn
import matplotlib.pyplot as plt
import matplotlib
from os import close
import backtrader as bt
from UsTicker import UsTicker
from ToolKit import ToolKit
from backtrader.feeds import PandasData
from datetime import datetime
import pandas as pd
import time
from datetime import datetime, timedelta
from MyEmail import MyEmail
import seaborn as sns
from backtrader_plotting import Bokeh
from backtrader_plotting.schemes import Tradimo
from BTUsStrategy import BTUsStrategy


if __name__ == '__main__':

    cerebro = bt.Cerebro()
    # Add a strategy
    # cerebro.addstrategy(StrategyOne)
    cerebro.addstrategy(BTUsStrategy)
    cerebro.broker.setcash(1000000.0)
    cerebro.addsizer(bt.sizers.FixedSize, stake=10)
    cerebro.broker.setcommission(commission=0.001)

    # Add Data
    trade_date = ToolKit('获取最新美股交易日期').get_latest_trade_date(1)
    list = UsTicker(trade_date).get_backtrader_data_feed_test()
    for h in list:
        data = bt.feeds.PandasData(
            dataname=h, name=h['symbol'][0], fromdate=datetime(2021, 1, 1))
        # Add a data
        cerebro.adddata(data)
        # 周数据
        # cerebro.resampledata(data, timeframe=bt.TimeFrame.Weeks, compression=1)

    print('Starting Portfolio Value: %.2f' % cerebro.broker.getvalue())

    cerebro.run()

    print('Final Portfolio Value: %.2f' % cerebro.broker.getvalue())
    cerebro.plot(style='bar')
    # b = Bokeh(style='bar', plot_mode='single', scheme=Tradimo())
    # cerebro.plot(b)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>
# 获取最新美股交易日期开始处理...
# 当前获取的美股日期是： 20211029
#
# 加载历史数据开始处理...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_12769/590531875.py in <module>
#      33     # Add Data
#      34     trade_date = ToolKit('获取最新美股交易日期').get_latest_trade_date(1)
# ---> 35     list = UsTicker(trade_date).get_backtrader_data_feed_test()
#      36     for h in list:
#      37         data = bt.feeds.PandasData(
#
# ~/miniconda3/myproject/finance/UsTicker.py in get_backtrader_data_feed_test(self)
#     106         # for i in tickers:
#     107         for i in ['BABA']:
# --> 108             t.progress_bar(len(tickers), tickers.index(i))
#     109             df = his_data.groupby(by='symbol').get_group(i)
#     110             # 过滤历史数据不完整的股票
#
# ValueError: 'BABA' is not in list
