# %%
#!/usr/bin/env python3
# -*- coding: UTF-8 -*-

from os import close
import backtrader as bt
from utility.ToolKit import ToolKit
from datetime import datetime
from datetime import datetime, timedelta
from backtrader_plotting import Bokeh
from backtrader_plotting.schemes import Tradimo
from backtraderref.BTStrategyVol import BTStrategyVol
from utility.TickerInfo import TickerInfo
from backtraderref.BTPandasDataExt import BTPandasDataExt
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import pyfolio as pf
import pandas as pd


if __name__ == "__main__":

    """创建cerebro对象"""
    cerebro = bt.Cerebro()
    """ 添加bt相关的策略 """
    cerebro.addstrategy(BTStrategyVol)
    """ 初始资金100M """
    cerebro.broker.setcash(1000000.0)
    """ 每手10股 """
    cerebro.addsizer(bt.sizers.FixedSize, stake=100)
    """ 费率千分之一 """
    cerebro.broker.setcommission(commission=0.001, stocklike=True)
    """ 添加股票当日即历史数据 """
    trade_date = ToolKit("获取最新A股交易日期").get_cn_latest_trade_date(1)
    list = TickerInfo(trade_date, "cn").get_backtrader_data_feed()
    """ 循环初始化数据进入cerebro """
    for h in list:
        print("正在初始化: ", h["symbol"][0])
        """ 历史数据最早不超过2021-01-01 """
        data = BTPandasDataExt(
            dataname=h, name=h["symbol"][0], fromdate=datetime(2021, 1, 1)
        )
        cerebro.adddata(data)

    print("Starting Portfolio Value: %.2f" % cerebro.broker.getvalue())

    # 回测时需要添加 TimeReturn 分析器
    cerebro.addanalyzer(bt.analyzers.TimeReturn, _name='_TimeReturn')
    result = cerebro.run()

    print("当前现金持有: ", cerebro.broker.get_cash())
    print("Final Portfolio Value: %.2f" % cerebro.broker.getvalue())

    # 提取收益序列
    pnl = pd.Series(result[0].analyzers._TimeReturn.get_analysis())

    # 计算累计收益
    cumulative = (pnl + 1).cumprod()

    # 计算回撤序列
    max_return = cumulative.cummax()

    drawdown = (cumulative - max_return) / max_return

    # 按年统计收益指标
    perf_stats_year = (
        (pnl)
        .groupby(pnl.index.to_period("y"))
        .apply(lambda data: pf.timeseries.perf_stats(data))
        .unstack()
    )

    # 统计所有时间段的收益指标
    perf_stats_all = pf.timeseries.perf_stats((pnl)).to_frame(name="all")

    perf_stats = pd.concat([perf_stats_year, perf_stats_all.T], axis=0)

    perf_stats_ = round(perf_stats, 4).reset_index()


    # 绘制图形

    plt.rcParams["axes.unicode_minus"] = False  # 用来正常显示负号

    # 导入设置坐标轴的模块
    plt.style.use("seaborn")
    plt.style.use('dark_background')

    fig, (ax0, ax1) = plt.subplots(
        2, 1, gridspec_kw={"height_ratios": [1.5, 4]}, figsize=(20, 8)
    )

    cols_names = [
        "date",
        "Annual\nreturn",
        "Cumulative\nreturns",
        "Annual\nvolatility",
        "Sharpe\nratio",
        "Calmar\nratio",
        "Stability",
        "Max\ndrawdown",
        "Omega\nratio",
        "Sortino\nratio",
        "Skew",
        "Kurtosis",
        "Tail\nratio",
        "Daily value\nat risk",
    ]


    # 绘制表格
    ax0.set_axis_off()
    # 除去坐标轴
    table = ax0.table(
        cellText=perf_stats_.values,
        bbox=(0, 0, 1, 1),
        # 设置表格位置， (x0, y0, width, height)
        rowLoc="right",
        # 行标题居中
        cellLoc="right",
        colLabels=cols_names,
        # 设置列标题
        colLoc="right",
        # 列标题居中
        edges="open",  # 不显示表格边框
    )

    table.set_fontsize(13)


    # 绘制累计收益曲线
    ax2 = ax1.twinx()

    ax1.yaxis.set_ticks_position("right")
    # 将回撤曲线的 y 轴移至右侧
    ax2.yaxis.set_ticks_position("left")
    # 将累计收益曲线的 y 轴移至左侧
    # 绘制回撤曲线
    drawdown.plot.area(
        ax=ax1, label="drawdown (right)", rot=0, alpha=0.3, fontsize=13, grid=False
    )

    # 绘制累计收益曲线
    (cumulative).plot(
        ax=ax2,
        color="#F1C40F",
        lw=3.0,
        label="cumret (left)",
        rot=0,
        fontsize=13,
        grid=False,
    )

    # 不然 x 轴留有空白
    ax2.set_xbound(lower=cumulative.index.min(), upper=cumulative.index.max())

    # 主轴定位器：每 5 个月显示一个日期：根据具体天数来做排版
    ax2.xaxis.set_major_locator(ticker.MultipleLocator(100))

    # 同时绘制双轴的图例
    h1, l1 = ax1.get_legend_handles_labels()

    h2, l2 = ax2.get_legend_handles_labels()

    plt.legend(h1 + h2, l1 + l2, fontsize=12, loc="upper left", ncol=1)


    fig.tight_layout()
    # 规整排版
    plt.show()
# Out:
# 加载历史数据...
# 正在处理股票：正在处理股票：正在处理股票：  正在处理股票：SZ301130正在处理股票：
#  正在处理股票：SZ300086 正在处理股票：
#  SZ300605正在处理股票：SZ300249SZ300338
#
#  正在处理股票：
# SZ300666
#  正在处理股票：SZ300199正在处理股票：正在处理股票：SZ300387正在处理股票：
# 正在处理股票：SZ300343正在处理股票：
# 正在处理股票：SZ300846SZ300782
#
#  SZ300584
# SZ000816SZ300604SZ300655正在处理股票： SZ002325SZ300665
#
# SZ000595
# 正在处理股票： 正在处理股票：
#
#
#
# SZ002354
# 正在处理股票：正在处理股票：正在处理股票：正在处理股票：
# 正在处理股票：正在处理股票：正在处理股票：    正在处理股票：   SZ000788SZ002381SZ002873SZ002125 SZ002748SZ002621SZ000859
#
#
#
#
#
# 正在处理股票：正在处理股票： SZ002402
#
# SZ002617正在处理股票：正在处理股票：
# 正在处理股票：  SZ002955  SZ002308正在处理股票：正在处理股票：正在处理股票：正在处理股票：SZ002497SZ002326
# 正在处理股票：
# SZ000987SZ003042
# 正在处理股票：
#
#  SZ002162
#    SZ002644正在处理股票： SZ002842SZ002667SZ002771
#
#
#
# 正在处理股票：正在处理股票：正在处理股票：正在处理股票： 正在处理股票：  正在处理股票：正在处理股票：SZ002068 正在处理股票：  SZ002132
#  SZ000766SZ000532SZ002725SZ002999
#
#
# 正在处理股票：正在处理股票：
# SZ300373正在处理股票：正在处理股票：正在处理股票：
#  SZ300167
#    SZ300223
# 正在处理股票：SZ300035SZ300346SZ300555SZ002529正在处理股票：正在处理股票：
#
#
#
# 正在处理股票：
#   正在处理股票：正在处理股票：正在处理股票：SZ002752SZ301058SZ002484
#
#  正在处理股票：
# SZ300041
#  SZ300306正在处理股票：SZ300623SZ300821
#
#
# 正在处理股票： 正在处理股票：正在处理股票：正在处理股票：SZ000963SZ300559正在处理股票： 正在处理股票：
#
# SZ300561  SZ002747
# SZ002043SZ300034
#
# SZ300350正在处理股票：
# 正在处理股票：正在处理股票：正在处理股票
在处理股票：正在处理股票：正在处理股票：
# 正在处理股票：正在处理股票：   正在处理股票： 正在处理股票：  SH600716SH601901SH600595 SH601877
# SH600331
# 正在处理股票：
# SH600257正在处理股票：
#
#
# SH600706SH600031  正在处理股票：正在处理股票：
# 正在处理股票：
#    SH601798正在处理股票：SH600516正在处理股票：正在处理股票：SH600338SH600643SH603169
#
#
#
# SH600268正在处理股票：
# SH600410正在处理股票：SH600537正在处理股票：
#
# 正在处理股票：
#  正在处理股票： 正在处理股票：SH600273SH600409正在处理股票：  正在处理股票：SH600623  SH600602
#
# SH600905SH600722
# SH603088 正在处理股票：
#
# 正在处理股票：
#  正在处理股票：正在处理股票：SH600105
# SH601919正在处理股票： 正在处理股票：SH600497
# SH601778
# 正在处理股票：SH600075
#
# 正在处理股票：SH601218正在处理股票：SH600901
# 正在处理股票：
#
# 正在处理股票： SH600104正在处理股票：SH600186 正在处理股票：正在处理股票：SH600111SH601868
#
# SH600586  SH600021
# 正在处理股票：
# 正在处理股票：
#
# SH600405 正在处理股票：SH601890正在处理股票：正在处理股票： SH600291正在处理股票：
#
#  SH600690
#   正在处理股票：正在处理股票：SH600804正在处理股票：SH600235SH600490 SH600906
# SH600006
#
#
#
#
# SH600529正在处理股票：正在处理股票：
# 正在处理股票：正在处理股票：SH600252 正在处理股票：
# SH600158正在处理股票：SH601016正在处理股票：正在处理股票：SH600095
# SH600667
#
#
# SH601608正在处理股票：正在处理股票：SH600373SH601375 SH600085
#  正在处理股票：
# 正在处理股票：
# SH600836正在处理股票：SH600112
#   正在处理股票：正在处理股票：正在处理股票：SH600025SH600816
#
#
#
#  正在处理股票：SH600390正在处理股票：SH601636SH600521正在处理股票：SH603815正在处理股票：
#
#
#   SH600196SH601015正在处理股票：SH600888
#
#
# 正在处理股票：正在处理股票：SH601669
#
#  正在处理股票： SH600428 SH601377
#
# SH601800
# SH600295正在处理股票：正在处理股票：正在处理股票：正在处理股票：正在处理股票：正在处理股票：
#  SH600855 正在处理股票： SH603393
#   正在处理股票：正在处理股票：  SH600396SH600682SH601311
# SH600109
# SH601066
#
# 正在处理股票：
#
# 正在处理股票：正在处理股票： 正在处理股票：SH600517   SH603766SH600880SH601555
#
#
# 正在处理股票：正在处理股票：正在处理股票：SH603019正在处理股票：SH600935
#
#  正在处理股票：  正在处理股票：  SH600814SH600530SH600308正在处理股票：
#
# SH601989 SH600879正在处理股票：正在处理股票：
#
# SH600478
# 正在处理股票：SH600151
#
#  SH600030正在处理股票：正在处理股票：SH600267 SH600724
# 正在处理股票：正在处理股票：
#
# 正在处理股票：正在处理股票：
#    SH601198SH601878SH600008
#  正在处理股票： SH600160
# 正在处理股票：SH601990
# 正在处理股票：SH600057 SH600321SH600790 SH601179
#
# 正在处理股票：
#
# 正在处理股票：正在处理股票：
#  正在处理股票：正在处理股票： SH601688SH600965
#  正在处理股票： 正在处理股票：SH601881
#
# SH600654 正在处理股票：
# SH600707 SH600737
# SH601700
# 正在处理股票：正在处理股票：正在处理股票： 正在处理股票：SH600169
#
#
# 正在处理股票：SH600192 SH600343
# SH600125正在处理股票：
# 正在处理股票：正在处理股票： SH603993
#
# 正在处理股票：SH603603SH600810 正在处理股票：正在处理股票：SH600103正在处理股票：
#  SH600176
#
#
# 正在处理股票：SH600918正在处理股票：正在处理股票：SH688538SH601696 正在处理股票：
#  SH600061 SH601717
#
# 正在处理股票：
# SH600166 正在处理股票：正在处理股票：SH600664
#
# SH601788正在处理股票：正在处理股票：SH601360
#  正在处理股票：
#
# 正在处理股票：SH601108
#   SH600127SH600340 SH600503
# 正在处理股票：SH601099SH601106
#
# SH601138
#
#
# 正在处理股票： SH600369
# 正在处理股票：正在处理股票： 正在处理股票：正在处理股票： SH600909  SH600633
# 正在处理股票：正在处理股票：SH601611SH601211
# 正在处理股票：正在处理股票：
#
# 正在处理股票：正在处理股票：正在处理股票：    SH600755SH600381SH603803SH600651
#
#   正在处理股票：
#  SH603817SH600303SH600336正在处理股票：
# 正在处理股票：正在处理股票：
# SH600435
#
# 正在处理股票：
# 正在处理股票： SH601162
# 正在处理股票： SH601728 正在处理股票：正在处理股票：正在处理股票：SH600635SH600507SH600808
# SH603701 正在处理股票：
# SH600572
#
# SH603636SH600307
# 正在处理股票：
# 正在处理股票： 正在处理股票：
#
#  SH600300正在处理股票：正在处理股票： 正在处理股票：
#   SH600837SH600479 SH600999SH600155
# SH600854正在处理股票：
# 正在处理股票：
#
# 正在处理股票：  正在处理股票：  SH600106正在处理股票：
#  正在处理股票：SH601216SH601991
#  SH600010
#
# 正在处理股票：SH603171正在处理股票：SH601117
#
# SH600773正在处理股票：正在处理股票：SH603000正在处理股票：
#
#  SH600535
# 正在处理股票：
# 正在处理股票：正在处理股票： SH601928 正在处理股票：
# SH601718SH601139SH600868 SH600251SH600567 正在处理股票：正在处理股票：
# SH603887
#
#
#  正在处理股票：
#
# 正在处理股票：SH600979 正在处理股票：正在处理股票：正在处理股票：SH600741   SH600039
# 正在处理股票：
# SH600705SH603318正在处理股票：
# SH601933 SH601399正在处理股票：
#
#
# 正在处理股票：正在处理股票：SH600388
# 正在处理股票：  SH601727 正在处理股票：
#  SH600812正在处理股票：SH600212SH601319SH600362 正在处理股票：
#
#
#
# SH600100
# 正在处理股票：正在处理股票：SH603610正在处理股票：正在处理股票：
# 正在处理股票：SH600576
#    SH600217正在处理股票： SH600185
# 正在处理股票：
#  SH600352SH600392正在处理股票：SH601958
#
#
#  SH603357正在处理股票：SH600271正在处理股票：SH600728
#
#  正在处理股票：正在处理股票： SH601866正在处理股票：正在处理股票：
# SH601766SH601665
#
#  SH601288正在处理股票：
# 正在处理股票：
# SH601975正在处理股票：SH601598正在处理股票：
#  正在处理股票：
#
#  正在处理股票：SH601000SH600801
# 正在处理股票：
#  SH601002
#    SH600881 SH600967正在处理股票：正在处理股票：正在处理股票：正在处理股票：
# SH600795SH600720
#  SH600717
# SH600653SH600657正在处理股票：
#
#
#
# 正在处理股票：SH600715正在处理股票：正在处理股票：正在处理股票：
# 正在处理股票： 正在处理股票：SH600582正在处理股票： SH600642
#  SH600320 SH600355正在处理股票：
# SH600518
# SH600439正在处理股票：
# 正在处理股票：
#
#  正在处理股票： SH600027
# 正在处理股票： SH600015 SH600337
#
# SH600050
#  SH600016
# 正在处理股票：正在处理股票： 正在处理股票：正在处理股票：SH600220正在处理股票： 正在处理股票： SH600926
#
# SH603083SH603336
# 正在处理股票：正在处理股票：SH600023
#   SH600380正在处理股票：
# SH600055 SH600740SH600886
# 正在处理股票：正在处理股票：
#  SH688009SH600070
#
#
# 正在处理股票： SH600900
# SH601398
# 正在处理股票：SH603335
# 正在处理股票：正在处理股票： 正在处理股票：正在处理股票：
#  正在处理股票：正在处理股票：SH600712
#  正在处理股票： SH600415 正在处理股票：SH601018SH600583SH600293
#
#
#
#  SH601168正在处理股票：正在处理股票：SH601038SH601618正在处理股票：SH600266
#  正在处理股票：正在处理股票：
#
#
#  正在处理股票： SH601318
#  正在处理股票：SH603555SH600839SH601988
#  SH600968
# 正在处理股票： SH600231正在处理股票：
# SH600467
# 正在处理股票：正在处理股票：SH601860SH601997
#
# 正在处理股票：  SH600704
# 正在处理股票： SH600187
# 正在处理股票：
#
#
# 正在处理股票： SH600403正在处理股票：
#  SH600310正在处理股票：SH601577
# 正在处理股票：
# 正在处理股票：SH601118正在处理股票：
# SH601011 SH600756
#
#  正在处理股票：正在处理股票： 正在处理股票：SH600297
# SH601187
#  SH601388
#
#  正在处理股票：SH601606SH601229SH600589
#  SH600121正在处理股票：正在处理股票： SH601199
# 正在处理股票： SH600863
#
# 正在处理股票：正在处理股票：正在处理股票：正在处理股票：正在处理股票： 正在处理股票：SH600649  正在处理股票：
#  SH600000SH600368SH601077SH601601 SH600133
#
# SH601005
#
# 正在处理股票：正在处理股票：正在处理股票：正在处理股票： SH601818
# SH603067
# 正在处理股票：
#  正在处理股票：
# 正在处理股票： 正在处理股票： 正在处理股票：SH600019    SH600571
#  SH601985SH600887SH600578SH601916
#
# 正在处理股票：SH600325
# SH601838SH601999
# SH600569
# 正在处理股票：
#
#
#
# 正在处理股票：正在处理股票：正在处理股票：正在处理股票：正在处理股票：正在处理股票：  正在处理股票：正在处理股票：  SH600208SH600499   SH600782SH600545
#
# SH600281
# SH601225正在处理股票：
# SH601169 SH600017
#
#
# 正在处理股票：
# SH600426
# 正在处理股票：SH600598正在处理股票： 正在处理股票：
# 正在处理股票： SH600971 正在处理股票：正在处理股票：正在处理股票：正在处理股票： SH603477
# SH601816
# 正在处理股票：SH600036
# SH600153SH600688SH600444正在处理股票：
# SH600138
# 正在处理股票：正在处理股票：正在处理股票：
# 正在处理股票： SH600668
# 正在处理股票： SH600146
#   SH600908
# SH600018
# 正在处理股票：
#
#    正在处理股票：正在处理股票：  正在处理股票：SH601186 SH600919正在处理股票：SH601328
#
# SH600823SH601998SH600035
#
# SH600820
# 正在处理股票：  SH601699SH600581
#
# 正在处理股票：正在处理股票： SH600348
# 正在处理股票：正在处理股票：
#
#  正在处理股票：SH600871 SH600531
# 正在处理股票：正在处理股票： SH600004
#
#  正在处理股票：正在处理股票：正在处理股票：  SH600491
# 正在处理股票： SH600256
# 正在处理股票：
# SH601992 正在处理股票： SH603030
# 正在处理股票：SH600309   SH601233正在处理股票： 正在处理股票： SH600540
# SH600322
# SH600811
# 正在处理股票：
# 正在处理股票：SH600496 正在处理股票： 正在处理股票：SH600425
#   SH601939SH600201正在处理股票：
# SH600219SH600243
#
#
# 正在处理股票：
# 正在处理股票： 正在处理股票：
# 正在处理股票：正在处理股票： SH600982
# SH603322
# 正在处理股票：  SH600180正在处理股票：
#   SH600359正在处理股票：  SH600282
# SH601658
# 正在处理股票：SH600655正在处理股票： SH600094
# 正在处理股票： SH601107正在处理股票：SH603969
#
# SH600429 正在处理股票：
# 正在处理股票： SH601101
#
#
#  SH603183 SH603843正在处理股票：正在处理股票：SH601006正在处理股票：
# SH603990
#  正在处理股票：
# SH600585
# SH600622
# 正在处理股票：正在处理股票：正在处理股票：
#  正在处理股票： SH600028
# 正在处理股票：正在处理股票： SH600606
# 正在处理股票： SH603881正在处理股票：
#  SH600202SH600997SH601212SH601668
#
#
# 正在处理股票：
# 正在处理股票： SH600528
# 正在处理股票： SH600284正在处理股票：
# 正在处理股票： 正在处理股票：正在处理股票： SH601456  SH601128  SH603918SH600162
# SH601009
#  正在处理股票：SH600903
# SH600505
#
# 正在处理股票：
# 正在处理股票：正在处理股票：SH601918正在处理股票：
#   SH600395SH600866SH600758正在处理股票：
#
#
# SH601111
#  正在处理股票：正在处理股票：SH600354正在处理股票：SH600665
# 正在处理股票：正在处理股票： SH600708
#
# 正在处理股票：SH600477SH601600
# 正在处理股票：
#
#  正在处理股票： SH600791
# SH688223正在处理股票：
# 正在处理股票： 正在处理股票： SH603003SH600565SH603323
# 正在处理股票：   SH600981
# 正在处理股票：
# 正在处理股票：
#  SH600123
# 正在处理股票：正在处理股票：正在处理股票： SH600054
# SH600009SH600029 正在处理股票：SH600159 SH601007 SH600751
#
#
#
# SH601898SH601333
# 正在处理股票：正在处理股票：正在处理股票：  SH601588正在处理股票：
# SH601857
#
# 正在处理股票：SH600048
#
# 正在处理股票：正在处理股票：   SH600743SH600446
# SH600077
#
#  SH600108
# 正在处理股票： SH603227
# 正在处理股票： SH601390正在处理股票：
# 正在处理股票：正在处理股票：正在处理股票：正在处理股票： 正在处理股票： SH600502SH601068
#  SH600547SH600126SH601166
#
#
#  正在处理股票：
# 正在处理股票：正在处理股票： 正在处理股票：正在处理股票：  SH600975SH603668
#
#  SH601899SH603018正在处理股票：正在处理股票：SH601952
#
#
# SH600872正在处理股票：正在处理股票：
#  SH600333正在处理股票：正在处理股票： 正在处理股票： SH600115
#  SH601069SH600339 正在处理股票：
#
# SH601001
# 正在处理股票：SH600759SH600489
#  正在处理股票：
# 正在处理股票：SH600988SH600985
# 正在处理股票：正在处理股票：SH600346正在处理股票：
#  SH600122正在处理股票：
# SH605169
#
# 正在处理股票： SH603619SH600383
# SH603825
# 正在处理股票：正在处理股票： 正在处理股票：正在处理股票： SH600397SH600533
# SH600170 SH603176
#
# 正在处理股票：
# 正在处理股票： SH600853
# 正在处理股票：正在处理股票：正在处理股票： 正在处理股票： SH601088SH601666
#
#  正在处理股票：SH600916 SH600313
# SH603363SH603316
#
#
#  正在处理股票：SH600512正在处理股票： SH600546
# 正在处理股票： 正在处理股票：
#  SH600188
# SH601155
#
#
# 正在处理股票：正在处理股票：  正在处理股票：SH600684正在处理股票： SH600371SH603679
#
# SH603138
# 正在处理股票：正在处理股票：SH600248正在处理股票：
# 正在处理股票：
# 正在处理股票：  正在处理股票： SH603717SH603123SH603388  SH600629SH603616
#
#
#
# SH600939
#
# 加载历史数据: 1%:  ▋
