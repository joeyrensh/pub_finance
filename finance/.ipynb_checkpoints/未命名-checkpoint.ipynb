# %%
#!/usr/bin/env python3
# -*- coding: UTF-8 -*-
from utility.FileInfo import FileInfo
from tabulate import tabulate
from utility.ToolKit import ToolKit
from utility.MyEmail import MyEmail
from datetime import datetime, timedelta
import pandas as pd
import seaborn as sns
from backtraderref.BTStrategy import BTStrategy
import backtrader as bt
from utility.TickerInfo import TickerInfo
from uscrawler.EMWebCrawler import EMWebCrawler
from uscrawler.EMUsTickerCategoryCrawler import EMUsTickerCategoryCrawler
from backtraderref.BTPandasDataExt import BTPandasDataExt
from cncrawler.EMCNWebCrawler import EMCNWebCrawler

""" backtrader策略 """


def exec_btstrategy(date):
    """ 创建cerebro对象 """
    cerebro = bt.Cerebro()
    """ 添加bt相关的策略 """
    cerebro.addstrategy(BTStrategy)
    """ 初始资金100M """
    cerebro.broker.setcash(1000000.0)
    """ 每手10股 """
    cerebro.addsizer(bt.sizers.FixedSize, stake=10)
    """ 费率千分之一 """
    cerebro.broker.setcommission(commission=0.001)
    """ 添加股票当日即历史数据 """
    list = TickerInfo(date, 'us').get_backtrader_data_feed_test()
    """ 循环初始化数据进入cerebro """
    for h in list:
        print("正在初始化: ", h['symbol'][0])
        """ 历史数据最早不超过2021-01-01 """
        data = BTPandasDataExt(
            dataname=h, name=h['symbol'][0], fromdate=datetime(2021, 1, 1))
        cerebro.adddata(data)
        # 周数据
        # cerebro.resampledata(data, timeframe=bt.TimeFrame.Weeks, compression=1)
    """ 起始资金池 """
    print('Starting Portfolio Value: %.2f' % cerebro.broker.getvalue())
    """ 运行cerebro """
    cerebro.run()
    """ 最终资金池 """
    print('当前现金持有: ', cerebro.broker.get_cash())
    print('Final Portfolio Value: %.2f' % cerebro.broker.getvalue())
    """ 画图相关 """
    cerebro.plot()


# 主程序入口
if __name__ == '__main__':

    trade_date = ToolKit('获取最新A股交易日期').get_cn_latest_trade_date(1)
    exec_btstrategy(trade_date)
# Out:
# 获取最新A股交易日期开始处理...
# 当前获取的A股日期是： 20220104
#
# 获取上一个交易日开始处理...
# 当前获取的美股日期是： 20220104
#
# 加载历史数据开始处理...
# 正在处理股票： AEHR
# 加载历史数据处理进度: 0%:  正在初始化:  AEHR
# Starting Portfolio Value: 1000000.00
#
# 获取最新交易日期开始处理...
# 当前获取的美股日期是： 20220105
#
# 获取上一个交易日开始处理...
# 当前获取的美股日期是： 20220104
#
# 策略初始化开始处理...
# 策略初始化处理进度: 0%:  2021-01-04, Buy AEHR Created 2.42
# 2021-01-05, Buy AEHR Executed, Price: 2.38
# 2021-02-26, Sell AEHR Created 2.80
# 2021-03-01 Sell AEHR Executed, Price: 3.01
# 2021-03-01, Operation Profit, Gross 6.30, Net 6.25
# 2021-03-01, Buy AEHR Created 3.09
# 2021-03-02, Buy AEHR Executed, Price: 3.10
# 2021-03-03, Sell AEHR Created 2.81
# 2021-03-04 Sell AEHR Executed, Price: 2.74
# 2021-03-04, Operation Profit, Gross -3.60, Net -3.66
# 2021-03-04, Buy AEHR Created 2.35
# 2021-03-05, Buy AEHR Executed, Price: 2.31
# 2021-03-08, Sell AEHR Created 2.34
# 2021-03-09 Sell AEHR Executed, Price: 2.40
# 2021-03-09, Operation Profit, Gross 0.90, Net 0.85
# 2021-03-09, Buy AEHR Created 2.44
# 2021-03-10, Buy AEHR Executed, Price: 2.50
# 2021-04-07, Sell AEHR Created 2.47
# 2021-04-08 Sell AEHR Executed, Price: 2.53
# 2021-04-08, Operation Profit, Gross 0.30, Net 0.25
# 2021-04-26, Buy AEHR Created 2.35
# 2021-04-27, Buy AEHR Executed, Price: 2.38
# 2021-04-29, Sell AEHR Created 2.31
# 2021-04-30 Sell AEHR Executed, Price: 2.29
# 2021-04-30, Operation Profit, Gross -0.90, Net -0.95
# 2021-05-19, Buy AEHR Created 2.42
# 2021-05-20, Buy AEHR Executed, Price: 2.53
# 2021-05-21, Sell AEHR Created 2.16
# 2021-05-24 Sell AEHR Executed, Price: 2.19
# 2021-05-24, Operation Profit, Gross -3.40, Net -3.45
# 2021-06-07, Buy AEHR Created 2.74
# 2021-06-08, Buy AEHR Executed, Price: 2.74
# 2021-06-18, Sell AEHR Created 2.44
# 2021-06-21 Sell AEHR Executed, Price: 2.44
# 2021-06-21, Operation Profit, Gross -3.00, Net -3.05
# 2021-06-23, Buy AEHR Created 2.58
# 2021-06-24, Buy AEHR Executed, Price: 2.59
# 2021-06-25, Sell AEHR Created 2.59
# 2021-06-28 Sell AEHR Executed, Price: 2.56
# 2021-06-28, Operation Profit, Gross -0.30, Net -0.35
# 2021-06-28, Buy AEHR Created 2.66
# 2021-06-29, Buy AEHR Executed, Price: 2.70
# 2021-07-06, Sell AEHR Created 2.50
# 2021-07-07 Sell AEHR Executed, Price: 2.48
# 2021-07-07, Operation Profit, Gross -2.20, Net -2.25
# 2021-07-09, Buy AEHR Created 2.72
# 2021-07-12, Buy AEHR Executed, Price: 2.72
# 2021-08-12, Sell AEHR Created 5.77
# 2021-08-13 Sell AEHR Executed, Price: 5.68
# 2021-08-13, Operation Profit, Gross 29.60, Net 29.52
# 2021-08-23, Buy AEHR Created 5.83
# 2021-08-24, Buy AEHR Executed, Price: 6.11
# 2021-11-18, Sell AEHR Created 19.61
# 2021-11-19 Sell AEHR Executed, Price: 18.84
# 2021-11-19, Operation Profit, Gross 127.30, Net 127.05
# 2021-12-22, Buy AEHR Created 19.07
# 2021-12-23, Buy AEHR Executed, Price: 19.08
#
# 最新交易日开始处理...
# 当前获取的美股日期是： 20220105
# 当前股票: AEHR, 交易天数: 9, 累计涨幅: 0.15618448637316565
# 当前现金持有:  999959.2170000001
# Final Portfolio Value: 1000179.82
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipykernel_32092/403435492.py in <module>
#      56
#      57     trade_date = ToolKit('获取最新A股交易日期').get_cn_latest_trade_date(1)
# ---> 58     exec_btstrategy(trade_date)
#
# /tmp/ipykernel_32092/403435492.py in exec_btstrategy(date)
#      49     print('Final Portfolio Value: %.2f' % cerebro.broker.getvalue())
#      50     """ 画图相关 """
# ---> 51     cerebro.plot(iplot=True, subplot=True)
#      52
#      53
#
# ~/miniconda3/lib/python3.9/site-packages/backtrader/cerebro.py in plot(self, plotter, numfigs, iplot, start, end, width, height, dpi, tight, use, **kwargs)
#     972
#     973         if not plotter:
# --> 974             from . import plot
#     975             if self.p.oldsync:
#     976                 plotter = plot.Plot_OldSync(**kwargs)
#
# ~/miniconda3/lib/python3.9/site-packages/backtrader/plot/__init__.py in <module>
#      40
#      41
# ---> 42 from .plot import Plot, Plot_OldSync
#      43 from .scheme import PlotScheme
#
# ~/miniconda3/lib/python3.9/site-packages/backtrader/plot/plot.py in <module>
#      42 from .finance import plot_candlestick, plot_ohlc, plot_volume, plot_lineonclose
#      43 from .formatters import (MyVolFormatter, MyDateFormatter, getlocator)
# ---> 44 from . import locator as loc
#      45 from .multicursor import MultiCursor
#      46 from .scheme import PlotScheme
#
# ~/miniconda3/lib/python3.9/site-packages/backtrader/plot/locator.py in <module>
#      33 from matplotlib.dates import AutoDateFormatter as ADFormatter
#      34
# ---> 35 from matplotlib.dates import (HOURS_PER_DAY, MIN_PER_HOUR, SEC_PER_MIN,
#      36                               MONTHS_PER_YEAR, DAYS_PER_WEEK,
#      37                               SEC_PER_HOUR, SEC_PER_DAY,
#
# ImportError: cannot import name 'warnings' from 'matplotlib.dates' (/root/miniconda3/lib/python3.9/site-packages/matplotlib/dates.py)
