# %%
#!/usr/bin/env python3
# -*- coding: UTF-8 -*-

from os import close
import backtrader as bt
from utility.ToolKit import ToolKit
from datetime import datetime
from datetime import datetime, timedelta
from backtrader_plotting import Bokeh
from backtrader_plotting.schemes import Tradimo
from backtraderref.BTStrategyVol import BTStrategyVol
from utility.TickerInfo import TickerInfo
from backtraderref.BTPandasDataExt import BTPandasDataExt
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import pyfolio as pf
import pandas as pd


if __name__ == "__main__":

    """创建cerebro对象"""
    cerebro = bt.Cerebro()
    """ 添加bt相关的策略 """
    cerebro.addstrategy(BTStrategyVol)
    """ 初始资金100M """
    cerebro.broker.setcash(1000000.0)
    """ 每手10股 """
    cerebro.addsizer(bt.sizers.FixedSize, stake=100)
    """ 费率千分之一 """
    cerebro.broker.setcommission(commission=0.001, stocklike=True)
    """ 添加股票当日即历史数据 """
    trade_date = ToolKit("获取最新A股交易日期").get_cn_latest_trade_date(0)
    list = TickerInfo(trade_date, "cn").get_backtrader_data_feed()
    """ 循环初始化数据进入cerebro """
    for h in list:
        print("正在初始化: ", h["symbol"][0])
        """ 历史数据最早不超过2021-01-01 """
        data = BTPandasDataExt(
            dataname=h, name=h["symbol"][0], fromdate=datetime(2021, 1, 1)
        )
        cerebro.adddata(data)

    print("Starting Portfolio Value: %.2f" % cerebro.broker.getvalue())

    # 回测时需要添加 TimeReturn 分析器
    cerebro.addanalyzer(bt.analyzers.TimeReturn, _name='_TimeReturn')
    result = cerebro.run()

    print("当前现金持有: ", cerebro.broker.get_cash())
    print("Final Portfolio Value: %.2f" % cerebro.broker.getvalue())

    # 提取收益序列
    pnl = pd.Series(result[0].analyzers._TimeReturn.get_analysis())

    # 计算累计收益
    cumulative = (pnl + 1).cumprod()

    # 计算回撤序列
    max_return = cumulative.cummax()

    drawdown = (cumulative - max_return) / max_return

    # 按年统计收益指标
    perf_stats_year = (
        (pnl)
        .groupby(pnl.index.to_period("y"))
        .apply(lambda data: pf.timeseries.perf_stats(data))
        .unstack()
    )

    # 统计所有时间段的收益指标
    perf_stats_all = pf.timeseries.perf_stats((pnl)).to_frame(name="all")

    perf_stats = pd.concat([perf_stats_year, perf_stats_all.T], axis=0)

    perf_stats_ = round(perf_stats, 4).reset_index()


    # 绘制图形

    plt.rcParams["axes.unicode_minus"] = False  # 用来正常显示负号

    # 导入设置坐标轴的模块
    plt.style.use("seaborn")
    plt.style.use('dark_background')

    fig, (ax0, ax1) = plt.subplots(
        2, 1, gridspec_kw={"height_ratios": [1.5, 4]}, figsize=(20, 8)
    )

    cols_names = [
        "date",
        "Annual\nreturn",
        "Cumulative\nreturns",
        "Annual\nvolatility",
        "Sharpe\nratio",
        "Calmar\nratio",
        "Stability",
        "Max\ndrawdown",
        "Omega\nratio",
        "Sortino\nratio",
        "Skew",
        "Kurtosis",
        "Tail\nratio",
        "Daily value\nat risk",
    ]


    # 绘制表格
    ax0.set_axis_off()
    # 除去坐标轴
    table = ax0.table(
        cellText=perf_stats_.values,
        bbox=(0, 0, 1, 1),
        # 设置表格位置， (x0, y0, width, height)
        rowLoc="right",
        # 行标题居中
        cellLoc="right",
        colLabels=cols_names,
        # 设置列标题
        colLoc="right",
        # 列标题居中
        edges="open",  # 不显示表格边框
    )

    table.set_fontsize(13)


    # 绘制累计收益曲线
    ax2 = ax1.twinx()

    ax1.yaxis.set_ticks_position("right")
    # 将回撤曲线的 y 轴移至右侧
    ax2.yaxis.set_ticks_position("left")
    # 将累计收益曲线的 y 轴移至左侧
    # 绘制回撤曲线
    drawdown.plot.area(
        ax=ax1, label="drawdown (right)", rot=0, alpha=0.3, fontsize=13, grid=False
    )

    # 绘制累计收益曲线
    (cumulative).plot(
        ax=ax2,
        color="#F1C40F",
        lw=3.0,
        label="cumret (left)",
        rot=0,
        fontsize=13,
        grid=False,
    )

    # 不然 x 轴留有空白
    ax2.set_xbound(lower=cumulative.index.min(), upper=cumulative.index.max())

    # 主轴定位器：每 5 个月显示一个日期：根据具体天数来做排版
    ax2.xaxis.set_major_locator(ticker.MultipleLocator(100))

    # 同时绘制双轴的图例
    h1, l1 = ax1.get_legend_handles_labels()

    h2, l2 = ax2.get_legend_handles_labels()

    plt.legend(h1 + h2, l1 + l2, fontsize=12, loc="upper left", ncol=1)


    fig.tight_layout()
    # 规整排版
    plt.show()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>
# /root/miniconda3/lib/python3.9/site-packages/pyfolio/pos.py:26: UserWarning: Module "zipline.assets" not found; mutltipliers will not be applied to position notionals.
#   warnings.warn(
# 获取最新A股交易日期...
# 当前获取的A股日期是： 20220223
#
# 获取上一个交易日...
# 当前获取的A股日期是： 20220223
#
# 加载历史数据...
# 正在处理股票：正在处理股票：  正在处理股票：SZ301130SZ300666正在处理股票：
# SZ300584正在处理股票：
# 正在处理股票： 正在处理股票：正在处理股票：正在处理股票： SZ300343正在处理股票：
#  正在处理股票：
#  SZ300665SZ002325SZ300249
#   SZ000595
# 正在处理股票： 正在处理股票：
# SZ002354SZ300604
# 正在处理股票：SZ000788正在处理股票：正在处理股票：
#
# SZ000859
# SZ000816正在处理股票：
#
#  正在处理股票：正在处理股票：正在处理股票：SZ002326SZ002381
#
#  SZ002402SZ002644正在处理股票： 正在处理股票：SZ002125SZ002617
#
# 正在处理股票：SZ002497 正在处理股票：
# SZ002132正在处理股票：
#
#  SZ003042
# 正在处理股票：正在处理股票：正在处理股票：SZ002725
#  正在处理股票：SZ300373SZ300035SZ000766
#
#
#
# 正在处理股票：正在处理股票：  正在处理股票：SZ300346正在处理股票：正在处理股票：  SZ301058
#  SZ300821SZ300350正在处理股票：
#
# SZ300041SZ002484
# SZ002747SZ300561SZ000963正在处理股票：
#
#
#
#
# 正在处理股票： 正在处理股票： SZ300034 SZ300497
# SZ300724
#
# 正在处理股票：正在处理股票：正在处理股票：  SZ300568
# 正在处理股票：正在处理股票：SZ000537正在处理股票：SZ300208正在处理股票：正在处理股票：正在处理股票：
#    SZ000768SZ002036SZ002158
#
#
#   SZ300485SZ002120
#
#
# SZ000546
# 正在处理股票： 正在处理股票：正在处理股票：正在处理股票：SZ002584
# SZ300398SZ002436正在处理股票：正在处理股票：  SZ003022SZ300314
#
#
#
# 正在处理股票：正在处理股票：正在处理股票： SZ002284
# 正在处理股票：正在处理股票：SZ300083 正在处理股票： SZ300671 SZ002895
# SZ002101正在处理股票：
# 正在处理股票：正在处理股票：正在处理股票：
#
#   正在处理股票：SZ300175 SZ300775
# SZ000887SZ002139
#
# SZ300263
# SZ002080正在处理股票：
#
# SZ300053
# 正在处理股票：正在处理股票： 正在处理股票：正在处理股票：SZ300118正在处理股票：正在处理股票：正在处理股票：SZ300319
#     SZ300026正在处理股票：SZ002606
# SZ002191SZ002709
#   正在处理股票：
# 正在处理股票：SZ002656
# SZ002318
#
#  SZ002323
# SZ002188正在处理股票：正在处理股票： 正在处理股票：
# 正在处理股票：  SZ300408
# 正在处理股票：
#  正在处理股票：SZ002079SZ000707
#
# SZ002404 正在处理股票：SZ002283 SZ002407
# 正在处理股票：
# 正在处理股票：SZ002336正在处理股票：   SZ002119SZ000988SZ000543
#
#
# 正在处理股票：SZ002415
# 正在处理股票：
# 正在处理股票： 正在处理股票：
# 正在处理股票：SZ002556正在处理股票： SZ002682 SZ002387
# SZ002241
#
#  SZ300316
#
# SZ002520
# 正在处理股票：正在处理股票：正在处理股票：正在处理股票：正在处理股票：  正在处理股票：正在处理股票：正在处理股票：    SZ300647SZ300059
# SZ000009正在处理股票：SZ300457
#
#   SZ300054 正在处理股票：
# SZ000738SZ300438
# SZ300450
# 正在处理股票：SZ000519正在处理股票：
#
#
#  正在处理股票： 正在处理股票：正在处理股票：正在处理股票： SZ002074
#  正在处理股票：SZ002202SZ002350正在处理股票：
# SZ300456SZ300274SZ002334 正在处理股票：
#
# SZ002412
# SZ002265正在处理股票：
#
# SZ002759正在处理股票：正在处理股票：正在处理股票：SZ300441SZ002610
#  正在处理股票：
#
# 正在处理股票： SZ300363SZ002340
#  SZ300565正在处理股票：
# 正在处理股票：
#
# 正在处理股票：正在处理股票：SZ002545正在处理股票：
# SZ002013正在处理股票：SZ300101
# 正在处理股票： 正在处理股票：SZ300276
# SZ000666
# SZ002639
#  SZ002206  正在处理股票：
# SZ002273
# SZ002475
# 正在处理股票：SZ002745
#
# 正在处理股票：正在处理股票：正在处理股票：SZ300446正在处理股票：正在处理股票：正在处理股票：
#  SZ300302 SZ300214
#
# 正在处理股票： SZ300006 SZ000301
# SZ300455
# 正在处理股票：SZ000828
#
#
# 正在处理股票：正在处理股票：  正在处理股票：SZ002272 SZ002765 SZ300204
#
# SZ000830SZ002149正在处理股票：
# SZ002452
# 正在处理股票：正在处理股票： 正在处理股票：
# 正在处理股票：正在处理股票： 正在处理股票： SZ300750 SZ000776  正在处理股票： SZ300393SZ300379
# SZ000540SZ300412SZ300129
# 正在处理股票：
#
#
#  SZ300323
#
# SZ300534正在处理股票：
#
#  SZ300147
# 正在处理股票：正在处理股票：正在处理股票：正在处理股票：正在处理股票： 正在处理股票：
#   File "/root/miniconda3/lib/python3.9/site-packages/zmq/sugar/context.py", line 190, in term
#     return super(Context, self).term()
# 正在处理股票：正在处理股票：
# Process ForkPoolWorker-2:
# Process ForkPoolWorker-7:
# Process ForkPoolWorker-8:
# SZ300001
# Process ForkPoolWorker-6:
# Process ForkPoolWorker-4:
# Process ForkPoolWorker-3:
# Process ForkPoolWorker-1:
# Process ForkPoolWorker-5:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/root/miniconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/root/miniconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/root/miniconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/root/miniconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/root/miniconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/root/miniconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/root/miniconda3/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/root/miniconda3/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/root/miniconda3/myproject/finance/utility/TickerInfo.py", line 125, in reconstruct_dataframe
#     print("正在处理股票：", i)
#   File "/root/miniconda3/myproject/finance/utility/TickerInfo.py", line 125, in reconstruct_dataframe
#     print("正在处理股票：", i)
#   File "/root/miniconda3/lib/python3.9/site-packages/ipykernel/iostream.py", line 537, in write
#     self.pub_thread.schedule(self._flush)
#   File "/root/miniconda3/lib/python3.9/site-packages/ipykernel/iostream.py", line 537, in write
#     self.pub_thread.schedule(self._flush)
#   File "/root/miniconda3/lib/python3.9/site-packages/ipykernel/iostream.py", line 216, in schedule
#     f()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/root/miniconda3/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/root/miniconda3/lib/python3.9/site-packages/ipykernel/iostream.py", line 216, in schedule
#     f()
#   File "/root/miniconda3/lib/python3.9/site-packages/ipykernel/iostream.py", line 497, in _flush
#     self.session.send(self.pub_thread, 'stream', content=content,
#   File "/root/miniconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/root/miniconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/root/miniconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/root/miniconda3/lib/python3.9/site-packages/jupyter_client/session.py", line 753, in send
#     stream.send_multipart(to_send, copy=copy)
#   File "/root/miniconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/root/miniconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/root/miniconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/root/miniconda3/lib/python3.9/site-packages/ipykernel/iostream.py", line 223, in send_multipart
#     self.schedule(lambda : self._really_send(*args, **kwargs))
#   File "/root/miniconda3/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/root/miniconda3/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/root/miniconda3/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/root/miniconda3/lib/python3.9/site-packages/ipykernel/iostream.py", line 216, in schedule
#     f()
#   File "/root/miniconda3/myproject/finance/utility/TickerInfo.py", line 125, in reconstruct_dataframe
#     print("正在处理股票：", i)
#   File "/root/miniconda3/myproject/finance/utility/TickerInfo.py", line 125, in reconstruct_dataframe
#     print("正在处理股票：", i)
#   File "/root/miniconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/root/miniconda3/lib/python3.9/site-packages/ipykernel/iostream.py", line 223, in <lambda>
#     self.schedule(lambda : self._really_send(*args, **kwargs))
# Traceback (most recent call last):
#   File "/root/miniconda3/lib/python3.9/site-packages/ipykernel/iostream.py", line 537, in write
#     self.pub_thread.schedule(self._flush)
#   File "/root/miniconda3/lib/python3.9/site-packages/ipykernel/iostream.py", line 537, in write
#     self.pub_thread.schedule(self._flush)
#   File "/root/miniconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/root/miniconda3/lib/python3.9/site-packages/ipykernel/iostream.py", line 216, in schedule
#     f()
#   File "/root/miniconda3/lib/python3.9/site-packages/ipykernel/iostream.py", line 216, in schedule
#     f()
#   File "/root/miniconda3/myproject/finance/utility/TickerInfo.py", line 125, in reconstruct_dataframe
#     print("正在处理股票：", i)
#   File "/root/miniconda3/lib/python3.9/site-packages/ipykernel/iostream.py", line 497, in _flush
#     self.session.send(self.pub_thread, 'stream', content=content,
#   File "/root/miniconda3/lib/python3.9/site-packages/ipykernel/iostream.py", line 497, in _flush
#     self.session.send(self.pub_thread, 'stream', content=content,
#   File "/root/miniconda3/lib/python3.9/site-packages/ipykernel/iostream.py", line 497, in _flush
#     self.session.send(self.pub_thread, 'stream', content=content,
#   File "/root/miniconda3/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/root/miniconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/root/miniconda3/lib/python3.9/site-packages/jupyter_client/session.py", line 753, in send
#     stream.send_multipart(to_send, copy=copy)
#   File "/root/miniconda3/lib/python3.9/site-packages/jupyter_client/session.py", line 753, in send
#     stream.send_multipart(to_send, copy=copy)
#   File "/root/miniconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/root/miniconda3/myproject/finance/utility/TickerInfo.py", line 125, in reconstruct_dataframe
#     print("正在处理股票：", i)
#   File "/root/miniconda3/lib/python3.9/site-packages/ipykernel/iostream.py", line 223, in send_multipart
#     self.schedule(lambda : self._really_send(*args, **kwargs))
#   File "/root/miniconda3/lib/python3.9/site-packages/ipykernel/iostream.py", line 223, in send_multipart
#     self.schedule(lambda : self._really_send(*args, **kwargs))
#   File "/root/miniconda3/myproject/finance/utility/TickerInfo.py", line 125, in reconstruct_dataframe
#     print("正在处理股票：", i)
#   File "/root/miniconda3/lib/python3.9/site-packages/ipykernel/iostream.py", line 537, in write
#     self.pub_thread.schedule(self._flush)
#   File "/root/miniconda3/lib/python3.9/site-packages/ipykernel/iostream.py", line 236, in _really_send
#     ctx, pipe_out = self._setup_pipe_out()
#   File "/root/miniconda3/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/root/miniconda3/lib/python3.9/site-packages/ipykernel/iostream.py", line 216, in schedule
#     f()
#   File "/root/miniconda3/lib/python3.9/site-packages/ipykernel/iostream.py", line 216, in schedule
#     f()
#   File "/root/miniconda3/lib/python3.9/site-packages/ipykernel/iostream.py", line 162, in _setup_pipe_out
#     pipe_out = ctx.socket(zmq.PUSH)
#   File "/root/miniconda3/myproject/finance/utility/TickerInfo.py", line 125, in reconstruct_dataframe
#     print("正在处理股票：", i)
#   File "/root/miniconda3/lib/python3.9/site-packages/ipykernel/iostream.py", line 223, in <lambda>
#     self.schedule(lambda : self._really_send(*args, **kwargs))
#   File "/root/miniconda3/lib/python3.9/site-packages/ipykernel/iostream.py", line 223, in <lambda>
#     self.schedule(lambda : self._really_send(*args, **kwargs))
#   File "/root/miniconda3/lib/python3.9/site-packages/ipykernel/iostream.py", line 537, in write
#     self.pub_thread.schedule(self._flush)
#   File "/root/miniconda3/lib/python3.9/site-packages/ipykernel/iostream.py", line 239, in _really_send
#     ctx.term()
#   File "/root/miniconda3/lib/python3.9/site-packages/ipykernel/iostream.py", line 239, in _really_send
#     ctx.term()
#   File "/root/miniconda3/lib/python3.9/site-packages/ipykernel/iostream.py", line 216, in schedule
#     f()
#   File "/root/miniconda3/lib/python3.9/site-packages/ipykernel/iostream.py", line 537, in write
#     self.pub_thread.schedule(self._flush)
#   File "/root/miniconda3/lib/python3.9/site-packages/zmq/sugar/context.py", line 190, in term
#     return super(Context, self).term()
#   File "/root/miniconda3/lib/python3.9/site-packages/zmq/sugar/context.py", line 190, in term
#     return super(Context, self).term()
#   File "/root/miniconda3/lib/python3.9/site-packages/jupyter_client/session.py", line 753, in send
#     stream.send_multipart(to_send, copy=copy)
#   File "/root/miniconda3/lib/python3.9/site-packages/ipykernel/iostream.py", line 216, in schedule
#     f()
#   File "/root/miniconda3/lib/python3.9/site-packages/ipykernel/iostream.py", line 537, in write
#     self.pub_thread.schedule(self._flush)
#   File "/root/miniconda3/lib/python3.9/site-packages/ipykernel/iostream.py", line 216, in schedule
#     f()
#   File "/root/miniconda3/lib/python3.9/site-packages/zmq/sugar/context.py", line 263, in socket
#     s = self._socket_class(  # set PYTHONTRACEMALLOC=2 to get the calling frame
#   File "/root/miniconda3/lib/python3.9/site-packages/ipykernel/iostream.py", line 223, in send_multipart
#     self.schedule(lambda : self._really_send(*args, **kwargs))
#   File "/root/miniconda3/lib/python3.9/site-packages/ipykernel/iostream.py", line 497, in _flush
#     self.session.send(self.pub_thread, 'stream', content=content,
#   File "/root/miniconda3/lib/python3.9/site-packages/ipykernel/iostream.py", line 497, in _flush
#     self.session.send(self.pub_thread, 'stream', content=content,
#   File "/root/miniconda3/lib/python3.9/site-packages/ipykernel/iostream.py", line 216, in schedule
#     f()
#   File "/root/miniconda3/lib/python3.9/site-packages/ipykernel/iostream.py", line 497, in _flush
#     self.session.send(self.pub_thread, 'stream', content=content,
#   File "/root/miniconda3/lib/python3.9/site-packages/jupyter_client/session.py", line 753, in send
#     stream.send_multipart(to_send, copy=copy)
#   File "/root/miniconda3/lib/python3.9/site-packages/jupyter_client/session.py", line 753, in send
#     stream.send_multipart(to_send, copy=copy)
#   File "/root/miniconda3/lib/python3.9/site-packages/jupyter_client/session.py", line 753, in send
#     stream.send_multipart(to_send, copy=copy)
#   File "/root/miniconda3/lib/python3.9/site-packages/ipykernel/iostream.py", line 223, in send_multipart
#     self.schedule(lambda : self._really_send(*args, **kwargs))
#   File "/root/miniconda3/lib/python3.9/site-packages/ipykernel/iostream.py", line 223, in send_multipart
#     self.schedule(lambda : self._really_send(*args, **kwargs))
#   File "/root/miniconda3/lib/python3.9/site-packages/ipykernel/iostream.py", line 223, in send_multipart
#     self.schedule(lambda : self._really_send(*args, **kwargs))
#   File "/root/miniconda3/lib/python3.9/site-packages/ipykernel/iostream.py", line 216, in schedule
#     f()
#   File "/root/miniconda3/lib/python3.9/site-packages/ipykernel/iostream.py", line 216, in schedule
#     f()
#   File "/root/miniconda3/lib/python3.9/site-packages/ipykernel/iostream.py", line 216, in schedule
#     f()
#   File "/root/miniconda3/lib/python3.9/site-packages/ipykernel/iostream.py", line 223, in <lambda>
#     self.schedule(lambda : self._really_send(*args, **kwargs))
#   File "/root/miniconda3/lib/python3.9/site-packages/ipykernel/iostream.py", line 223, in <lambda>
#     self.schedule(lambda : self._really_send(*args, **kwargs))
#   File "/root/miniconda3/lib/python3.9/site-packages/ipykernel/iostream.py", line 223, in <lambda>
#     self.schedule(lambda : self._really_send(*args, **kwargs))
#   File "/root/miniconda3/lib/python3.9/site-packages/ipykernel/iostream.py", line 239, in _really_send
#     ctx.term()
#   File "/root/miniconda3/lib/python3.9/site-packages/ipykernel/iostream.py", line 239, in _really_send
#     ctx.term()
#   File "zmq/backend/cython/context.pyx", line 82, in zmq.backend.cython.context.Context.term
#   File "/root/miniconda3/lib/python3.9/site-packages/ipykernel/iostream.py", line 239, in _really_send
#     ctx.term()
#   File "zmq/backend/cython/context.pyx", line 82, in zmq.backend.cython.context.Context.term
#   File "/root/miniconda3/lib/python3.9/site-packages/zmq/sugar/socket.py", line 83, in __init__
#     super().__init__(*a, **kw)
#   File "/root/miniconda3/lib/python3.9/site-packages/ipykernel/iostream.py", line 216, in schedule
#     f()
#   File "/root/miniconda3/lib/python3.9/site-packages/zmq/sugar/context.py", line 190, in term
#     return super(Context, self).term()
#   File "zmq/backend/cython/checkrc.pxd", line 13, in zmq.backend.cython.checkrc._check_rc
#   File "zmq/backend/cython/checkrc.pxd", line 13, in zmq.backend.cython.checkrc._check_rc
#   File "/root/miniconda3/lib/python3.9/site-packages/zmq/sugar/context.py", line 190, in term
#     return super(Context, self).term()
#   File "/root/miniconda3/lib/python3.9/site-packages/ipykernel/iostream.py", line 497, in _flush
#     self.session.send(self.pub_thread, 'stream', content=content,
# KeyboardInterrupt
#   File "zmq/backend/cython/context.pyx", line 82, in zmq.backend.cython.context.Context.term
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/root/miniconda3/lib/python3.9/site-packages/jupyter_client/session.py", line 753, in send
#     stream.send_multipart(to_send, copy=copy)
#   File "zmq/backend/cython/context.pyx", line 82, in zmq.backend.cython.context.Context.term
#   File "/root/miniconda3/lib/python3.9/site-packages/ipykernel/iostream.py", line 223, in <lambda>
#     self.schedule(lambda : self._really_send(*args, **kwargs))
#   File "zmq/backend/cython/checkrc.pxd", line 13, in zmq.backend.cython.checkrc._check_rc
#   File "zmq/backend/cython/checkrc.pxd", line 13, in zmq.backend.cython.checkrc._check_rc
#   File "/root/miniconda3/lib/python3.9/site-packages/zmq/sugar/context.py", line 190, in term
#     return super(Context, self).term()
#   File "zmq/backend/cython/checkrc.pxd", line 13, in zmq.backend.cython.checkrc._check_rc
#   File "zmq/backend/cython/context.pyx", line 82, in zmq.backend.cython.context.Context.term
#   File "/root/miniconda3/lib/python3.9/site-packages/ipykernel/iostream.py", line 239, in _really_send
#     ctx.term()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/root/miniconda3/lib/python3.9/site-packages/ipykernel/iostream.py", line 223, in send_multipart
#     self.schedule(lambda : self._really_send(*args, **kwargs))
# KeyboardInterrupt
#   File "zmq/backend/cython/context.pyx", line 82, in zmq.backend.cython.context.Context.term
#   File "zmq/backend/cython/checkrc.pxd", line 13, in zmq.backend.cython.checkrc._check_rc
#   File "/root/miniconda3/lib/python3.9/site-packages/ipykernel/iostream.py", line 216, in schedule
#     f()
# 正在处理股票：
#   File "/root/miniconda3/lib/python3.9/site-packages/ipykernel/iostream.py", line 223, in <lambda>
#     self.schedule(lambda : self._really_send(*args, **kwargs))
#  正在处理股票：
#   File "/root/miniconda3/lib/python3.9/site-packages/ipykernel/iostream.py", line 239, in _really_send
#     ctx.term()
#   File "/root/miniconda3/lib/python3.9/site-packages/zmq/sugar/context.py", line 190, in term
#     return super(Context, self).term()
# SZ300108
# KeyboardInterrupt
# 正在处理股票：
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_12280/1192829221.py in <module>
#      32     """ 添加股票当日即历史数据 """
#      33     trade_date = ToolKit("获取最新A股交易日期").get_cn_latest_trade_date(1)
# ---> 34     list = TickerInfo(trade_date, "cn").get_backtrader_data_feed()
#      35     """ 循环初始化数据进入cerebro """
#      36     for h in list:
#
# ~/miniconda3/myproject/finance/utility/TickerInfo.py in get_backtrader_data_feed(self)
#     108         pool.close()
#     109         """ 等待进程池中的所有进程执行完毕 """
# --> 110         pool.join()
#     111
#     112         """ 垃圾回收 """
#
# ~/miniconda3/lib/python3.9/multiprocessing/pool.py in join(self)
#     660         elif self._state not in (CLOSE, TERMINATE):
#     661             raise ValueError("In unknown state")
# --> 662         self._worker_handler.join()
#     663         self._task_handler.join()
#     664         self._result_handler.join()
#
# ~/miniconda3/lib/python3.9/threading.py in join(self, timeout)
#    1051
#    1052         if timeout is None:
# -> 1053             self._wait_for_tstate_lock()
#    1054         else:
#    1055             # the behavior of a negative timeout isn't documented, but
#
# ~/miniconda3/lib/python3.9/threading.py in _wait_for_tstate_lock(self, block, timeout)
#    1067         if lock is None:  # already determined that the C code is done
#    1068             assert self._is_stopped
# -> 1069         elif lock.acquire(block, timeout):
#    1070             lock.release()
#    1071             self._stop()
#
# KeyboardInterrupt:
#   File "zmq/backend/cython/context.pyx", line 82, in zmq.backend.cython.context.Context.term
#   File "zmq/backend/cython/checkrc.pxd", line 13, in zmq.backend.cython.checkrc._check_rc
# 正在处理股票：  正在处理股票：
# KeyboardInterrupt
# 正在处理股票：SZ300080 正在处理股票：SZ002446 SZ000930
#
# SZ300124SZ000591
# 正在处理股票：正在处理股票：
#
# 正在处理股票：  正在处理股票： SZ300123
# 正在处理股票：SZ002129SZ002297 正在处理股票： 正在处理股票：SZ002288
# SZ300376正在处理股票：正在处理股票：
#    SZ002156SZ000021SZ002236
#
#
#
#
#  SZ000338正在处理股票：正在处理股票：正在处理股票：
#   SZ002092SZ300058SZ002313
#
#
# 正在处理股票：正在处理股票：SZ002108
#  SZ000861正在处理股票：SZ000563
#
#  SZ300045正在处理股票：正在处理股票：正在处理股票： SZ000875
# 正在处理股票：正在处理股票：正在处理股票：正在处理股票：   SZ002389SZ300510SZ002538
#
#
#  正在处理股票： 正在处理股票：  SZ002476SZ000822
#
#
# 正在处理股票：正在处理股票：正在处理股票：SZ300692SZ000592   SZ002459
# SZ002414
#
# 正在处理股票：正在处理股票：正在处理股票：正在处理股票：
# 正在处理股票：SZ300009  SZ000723SZ002498SZ002232SZ002481
#
#
# 正在处理股票：
#
# 正在处理股票：正在处理股票：正在处理股票：  SZ002185正在处理股票：SZ000019SZ002496 SZ300163
#
#
#
# 正在处理股票：正在处理股票：SZ000893
#
# 正在处理股票：SZ300102 正在处理股票：SZ002309SZ300177
# 正在处理股票：正在处理股票：正在处理股票：  正在处理股票：正在处理股票：正在处理股票：正在处理股票：正在处理股票：SH601222
#    SH603767SH600456SH601126SH603778SH600618SH601615
#
# 正在处理股票：
# SH600366
#
#
#  正在处理股票：正在处理股票：
# 正在处理股票：正在处理股票： SH600992正在处理股票： 正在处理股票：   SH600584SH600893
#  正在处理股票：SH600699
#  SH601058SH601599
#
# 正在处理股票：SH601969
#
# 正在处理股票： SH688012
#
# 正在处理股票： SH600673
# SH601020正在处理股票：SH601012正在处理股票：
# 正在处理股票：正在处理股票：正在处理股票：
# 正在处理股票： SH601633SH600958 SH600577
#
# SH600406
# SH601908正在处理股票：
# 正在处理股票：
# 正在处理股票：SH600210  SH688660 SH600862
#
# 正在处理股票：
# 正在处理股票：正在处理股票：  正在处理股票：SH600328SH600760
#  SH600637正在处理股票：正在处理股票：
# 正在处理股票：
#    SH603027正在处理股票：SH600875SH603222SH600501正在处理股票：
#
#  正在处理股票：
# 正在处理股票：SH600765
#  SH600079正在处理股票： 正在处理股票： SH600033正在处理股票： SH600973
#
# SH600927
# SH600522
#  正在处理股票：SH600358
# 正在处理股票：正在处理股票：
# 正在处理股票：
# 正在处理股票：  SH603858正在处理股票：  正在处理股票：SH601966SH600218SH600698
#  SH603036
#
# SH600360
#
# 正在处理股票：
# SH601127正在处理股票：正在处理股票：
#   正在处理股票：正在处理股票： 正在处理股票：SH600120 SH600116
# 正在处理股票：
#  SH600400正在处理股票：  SH603077SH603799
#
#
#  SH600143 正在处理股票：SH601865正在处理股票：
#
#  SH601238 SH600038
# SH603566
#
# 正在处理股票：SH688599正在处理股票： SH600771
#
# 正在处理股票：正在处理股票：正在处理股票：  正在处理股票： 正在处理股票：SH601686
# 正在处理股票： SH600150 正在处理股票：
#
# SH600131正在处理股票：SH600556SH600636 正在处理股票： SH601330 SH601678正在处理股票：
#
# SH600335 SH603105
#
# SH603626SH600163
#
# 正在处理股票：
#
# 正在处理股票：正在处理股票：正在处理股票：正在处理股票：  SH600470SH600277
# 正在处理股票：正在处理股票：正在处理股票：  SH688779正在处理股票：   SH603789SH600860
#
# 正在处理股票：正在处理股票：
#  SH603259 正在处理股票：SH600515
# SH600873SH600438
#
# SH603011
#
#
# SH600227SH600255正在处理股票：正在处理股票：正在处理股票：正在处理股票：  正在处理股票：正在处理股票： SH600770
# SH603466SH603936SH600986
# SH603977SH600961
#
#
#
#
# 正在处理股票：正在处理股票：
#  正在处理股票：正在处理股票：正在处理股票：SH600199
# 正在处理股票：正在处理股票：SH603606    正在处理股票：SH600238
#  正在处理股票：
# SH600621SH600594 正在处理股票：
# SH600312
# 正在处理股票：SH600422
#  SH600129SH603598SH600727
#
# SH688981
#
#
# 正在处理股票：正在处理股票：  SH600821SH600089正在处理股票：
# 正在处理股票：正在处理股票： 正在处理股票：
# 正在处理股票： 正在处理股票：SH600011正在处理股票： 正在处理股票：
# SH600550
#   SH600549 SH600316SH603306
# SH600183
#
#
# 正在处理股票： SH600570SH600487 正在处理股票：SH600063
#
# 正在处理股票：正在处理股票： SH600552
#
# 正在处理股票： 正在处理股票： SH600500
# SH601619
# 正在处理股票：正在处理股票：SH601872
