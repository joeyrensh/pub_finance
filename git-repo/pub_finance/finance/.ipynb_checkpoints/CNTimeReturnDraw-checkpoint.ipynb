# %%
#!/usr/bin/env python3
# -*- coding: UTF-8 -*-

from os import close
import backtrader as bt
from utility.ToolKit import ToolKit
from datetime import datetime
from datetime import datetime, timedelta
from backtrader_plotting import Bokeh
from backtrader_plotting.schemes import Tradimo
from backtraderref.BTStrategyVol import BTStrategyVol
from utility.TickerInfo import TickerInfo
from backtraderref.BTPandasDataExt import BTPandasDataExt
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import pyfolio as pf
import pandas as pd


if __name__ == "__main__":

    """创建cerebro对象"""
    cerebro = bt.Cerebro()
    """ 添加bt相关的策略 """
    cerebro.addstrategy(BTStrategyVol)
    """ 初始资金100M """
    cerebro.broker.setcash(1000000.0)
    """ 每手10股 """
    cerebro.addsizer(bt.sizers.FixedSize, stake=100)
    """ 费率千分之一 """
    cerebro.broker.setcommission(commission=0.001, stocklike=True)
    """ 添加股票当日即历史数据 """
    trade_date = ToolKit("获取最新A股交易日期").get_cn_latest_trade_date(1)
    list = TickerInfo(trade_date, "cn").get_backtrader_data_feed()
    """ 循环初始化数据进入cerebro """
    for h in list:
        print("正在初始化: ", h["symbol"][0])
        """ 历史数据最早不超过2021-01-01 """
        data = BTPandasDataExt(
            dataname=h, name=h["symbol"][0], fromdate=datetime(2021, 1, 1)
        )
        cerebro.adddata(data)

    print("Starting Portfolio Value: %.2f" % cerebro.broker.getvalue())

    # 回测时需要添加 TimeReturn 分析器
    cerebro.addanalyzer(bt.analyzers.TimeReturn, _name='_TimeReturn')
    result = cerebro.run()

    print("当前现金持有: ", cerebro.broker.get_cash())
    print("Final Portfolio Value: %.2f" % cerebro.broker.getvalue())

    # 提取收益序列
    pnl = pd.Series(result[0].analyzers._TimeReturn.get_analysis())

    # 计算累计收益
    cumulative = (pnl + 1).cumprod()

    # 计算回撤序列
    max_return = cumulative.cummax()

    drawdown = (cumulative - max_return) / max_return

    # 按年统计收益指标
    perf_stats_year = (
        (pnl)
        .groupby(pnl.index.to_period("y"))
        .apply(lambda data: pf.timeseries.perf_stats(data))
        .unstack()
    )

    # 统计所有时间段的收益指标
    perf_stats_all = pf.timeseries.perf_stats((pnl)).to_frame(name="all")

    perf_stats = pd.concat([perf_stats_year, perf_stats_all.T], axis=0)

    perf_stats_ = round(perf_stats, 4).reset_index()


    # 绘制图形

    plt.rcParams["axes.unicode_minus"] = False  # 用来正常显示负号

    # 导入设置坐标轴的模块
    plt.style.use("seaborn")
    plt.style.use('dark_background')

    fig, (ax0, ax1) = plt.subplots(
        2, 1, gridspec_kw={"height_ratios": [1.5, 4]}, figsize=(20, 8)
    )

    cols_names = [
        "date",
        "Annual\nreturn",
        "Cumulative\nreturns",
        "Annual\nvolatility",
        "Sharpe\nratio",
        "Calmar\nratio",
        "Stability",
        "Max\ndrawdown",
        "Omega\nratio",
        "Sortino\nratio",
        "Skew",
        "Kurtosis",
        "Tail\nratio",
        "Daily value\nat risk",
    ]


    # 绘制表格
    ax0.set_axis_off()
    # 除去坐标轴
    table = ax0.table(
        cellText=perf_stats_.values,
        bbox=(0, 0, 1, 1),
        # 设置表格位置， (x0, y0, width, height)
        rowLoc="right",
        # 行标题居中
        cellLoc="right",
        colLabels=cols_names,
        # 设置列标题
        colLoc="right",
        # 列标题居中
        edges="open",  # 不显示表格边框
    )

    table.set_fontsize(13)


    # 绘制累计收益曲线
    ax2 = ax1.twinx()

    ax1.yaxis.set_ticks_position("right")
    # 将回撤曲线的 y 轴移至右侧
    ax2.yaxis.set_ticks_position("left")
    # 将累计收益曲线的 y 轴移至左侧
    # 绘制回撤曲线
    drawdown.plot.area(
        ax=ax1, label="drawdown (right)", rot=0, alpha=0.3, fontsize=13, grid=False
    )

    # 绘制累计收益曲线
    (cumulative).plot(
        ax=ax2,
        color="#F1C40F",
        lw=3.0,
        label="cumret (left)",
        rot=0,
        fontsize=13,
        grid=False,
    )

    # 不然 x 轴留有空白
    ax2.set_xbound(lower=cumulative.index.min(), upper=cumulative.index.max())

    # 主轴定位器：每 5 个月显示一个日期：根据具体天数来做排版
    ax2.xaxis.set_major_locator(ticker.MultipleLocator(100))

    # 同时绘制双轴的图例
    h1, l1 = ax1.get_legend_handles_labels()

    h2, l2 = ax2.get_legend_handles_labels()

    plt.legend(h1 + h2, l1 + l2, fontsize=12, loc="upper left", ncol=1)


    fig.tight_layout()
    # 规整排版
    plt.show()
# Out:
# 获取最新A股交易日期...
# 当前获取的A股日期是： 20220621
#
# 获取上一个交易日...
# 当前获取的A股日期是： 20220621
#
# 加载历史数据...
# 正在处理股票：正在处理股票：正在处理股票：正在处理股票： SZ300479正在处理股票：
#   正在处理股票：正在处理股票：正在处理股票：  SZ300660 SZ300891 SZ300585SZ300024
#
#
# SZ300657
# SZ301266正在处理股票：
# 正在处理股票：正在处理股票： SZ300293
# 正在处理股票：正在处理股票：  正在处理股票： SZ300400
# SZ000068
#
# SZ002519 SZ002031正在处理股票： SZ002482正在处理股票：SZ000589
#
# 正在处理股票：
# 正在处理股票：
# 正在处理股票：  正在处理股票：SZ002559SZ002527 正在处理股票：
#   SZ002047正在处理股票：
#  SZ002174SZ002703SZ001270
# SZ000037正在处理股票：正在处理股票：
#  SZ002638
#  SZ002848
#
#
#
# SZ002909
# 正在处理股票： 正在处理股票：正在处理股票：
# 正在处理股票：
# 正在处理股票： 正在处理股票：正在处理股票： 正在处理股票：SZ002380 SZ002347  SZ000403
# SZ000702
# SZ002403 SZ000020
# SZ002988
# 正在处理股票：正在处理股票：SZ002657
#
# 正在处理股票：SZ000627正在处理股票：   正在处理股票：正在处理股票：正在处理股票：SZ300222
# 正在处理股票：SZ300742 正在处理股票：
# SZ000880正在处理股票：   SZ002918
#
#  SZ002587SZ002204SZ300468正在处理股票：SZ300278
# SZ300607
# 正在处理股票：
#
#
#
#  正在处理股票： 正在处理股票：正在处理股票：正在处理股票：正在处理股票：SZ000584SZ002613正在处理股票：  SZ300626
#  SZ300097正在处理股票：
#    SZ300458
# SZ300364SZ300793
# 正在处理股票：SZ300688正在处理股票：
#
# 正在处理股票：
#
# 正在处理股票：SZ300250SZ300209
# SZ002892正在处理股票：SZ002996
# 正在处理股票：
#
#  SZ000546 SZ300565正在处理股票：正在处理股票：正在处理股票：  正在处理股票：SZ300486 正在处理股票： SZ000821正在处理股票： SZ300058
# SZ300052
#
# SZ002581
# SZ300044
# SZ300827
#
# 正在处理股票：正在处理股票：
#
#
# 正在处理股票：正在处理股票：正在处理股票： 正在处理股
# 正在处理股票：正在处理股票：正在处理股票：正在处理股票：正在处理股票： SH600201
# 正在处理股票：  SH600622
# 正在处理股票：正在处理股票：正在处理股票：
#    SH600082SH600496   SH600502
# 正在处理股票：SH601336SH600801SH601225正在处理股票：
# SH603378
#
#
#  SH603030
#
# 正在处理股票：正在处理股票：正在处理股票： SH601318 正在处理股票：正在处理股票：SH603938
# 正在处理股票：正在处理股票：
#
#  SH600327
# 正在处理股票：  正在处理股票：SH603078SH601800SH601228SH601985
#
# SH603390
#
# SH603225
#  SH600036正在处理股票：
# 正在处理股票：正在处理股票：正在处理股票：   SH600881SH600693SH603123
# 正在处理股票：  正在处理股票：正在处理股票：正在处理股票：
#  SH601601
# SH600639正在处理股票：正在处理股票：SH601816SH600678
# SH603429
#
# SH601992正在处理股票：
#
# 正在处理股票：正在处理股票： SH600162正在处理股票： SH600527
#  正在处理股票：SH600071
#
#  SH601878
# SH600030
#  SH600196
#
# 正在处理股票：正在处理股票：正在处理股票：正在处理股票：   正在处理股票：正在处理股票：正在处理股票：正在处理股票： SH600373 SH601009 SH600664SH600880SH600048
#
# SH601166
#
# SH600919
#
# SH601898正在处理股票：正在处理股票：
#
#  正在处理股票：正在处理股票： SH688599正在处理股票：正在处理股票：SH601398
#
#  正在处理股票：正在处理股票：正在处理股票：   正在处理股票：SH600938  SH600509SH600690SH600708SH600188
#
#
#  SH600243
# 正在处理股票：
# 正在处理股票：
# SH603555正在处理股票：正在处理股票： SH600797正在处理股票：正在处理股票：
# SH603115 SH600569 正在处理股票：
#     SH600297SH601668SH603843
#
#
# 正在处理股票：SH600637SH600590
#
#
# 正在处理股票： 正在处理股票：SH600684
# 正在处理股票：正在处理股票：
# SH600503
# SH600773
# 正在处理股票： SH600683SH603366
#
# 正在处理股票： 正在处理股票：正在处理股票：正在处理股票：正在处理股票：正在处理股票： SH601199   SH601818
# 正在处理股票：正在处理股票：SH600510   SH600185SH600452SH600123SH601328
# 正在处理股票：SH600578
#
#
#
#
#
# 正在处理股票：正在处理股票：SH601988  正在处理股票：
#  正在处理股票：正在处理股票：SH600715SH601916
# SH603023
# 正在处理股票：正在处理股票：
#   正在处理股票：SH600603SH600096SH600565
#
#
# SH601788
# 正在处理股票：正在处理股票：SH600235SH600641
# 正在处理股票：
# SH600556 正在处理股票：
# SH600901
# SH603097正在处理股票：正在处理股票：正在处理股票：SH601001
#  正在处理股票：
# 正在处理股票：正在处理股票：
# 正在处理股票：    正在处理股票：SH600439 SH600372SH603648SH600000SH605111 SH600836SH600770
# SH601003
#
#
#
#
#
# 正在处理股票： 正在处理股票：正在处理股票：正在处理股票：SH600973
# SH600740SH600355
#  正在处理股票：正在处理股票：SH600642
#
# SH600133正在处理股票：正在处理股票：
# 正在处理股票：正在处理股票：正在处理股票：    SH601101SH601169正在处理股票：
# 正在处理股票：
# SH601939SH600170 正在处理股票：
# SH601808正在处理股票：SH600557
#
#  SH600109正在处理股票：正在处理股票：
# SH600052正在处理股票： SH601718SH600055
#
#
# SH600295
# 正在处理股票：正在处理股票：SH600619
#
# 正在处理股票：正在处理股票：正在处理股票：SH600617 SH600782正在处理股票：SH600015
#
#  正在处理股票： 正在处理股票：
# 正在处理股票：SH600705  SH600300SH600446SH600602 正在处理股票：
# SH601699
#
#
# SH600398SH600023 正在处理股票：
# SH600748
#
#  正在处理股票： 正在处理股票：正在处理股票：SH600448
#
#
# 正在处理股票： 正在处理股票：正在处理股票：SH600808SH600606
# SH600859SH601077
#
#  SH600559
#
# SH600604正在处理股票：正在处理股票： SH600120SH603333
#
# 正在处理股票：正在处理股票：正在处理股票：正在处理股票：正在处理股票：  正在处理股票：正在处理股票：正在处理股票：    SH600369 SH601607SH600649SH600009
#  SH600905SH601088SH601211
# 正在处理股票：
#
#
#
# SH600791
# 正在处理股票：正在处理股票：
# 正在处理股票：  正在处理股票：SH600753正在处理股票：正在处理股票： 正在处理股票： SH601588 SH601918
# SH601998 SH601118
# SH600707SH601991正在处理股票：
#
#
# 正在处理股票：
#  正在处理股票：SH600021SH601868 SH600751 正在处理股票：
#
# 正在处理股票：正在处理股票：正在处理股票：
# SH600718
#
# SH601860SH600410 正在处理股票：
# SH601789 SH601099
# 正在处理股票：
# 正在处理股票： 正在处理股票：
# 正在处理股票：   正在处理股票：SH601138正在处理股票：
#  正在处理股票：SH603398SH600864SH600868SH601288正在处理股票：
#
#  SH600515
# SH600567
#
# 正在处理股票：正在处理股票：
# 正在处理股票：SH600720SH600635正在处理股票：正在处理股票：  正在处理股票：
#
#
#
# 正在处理股票：SH601006 SH601012 正在处理股票：SH600397SH601975
#
#  SH603399
# SH600016
# SH600266SH603363
# 正在处理股票：正在处理股票：正在处理股票：正在处理股票：
#
# 正在处理股票：正在处理股票：  正在处理股票：正在处理股票：SH601008SH600758SH600425
# SH600717SH600184SH600183SH600939正在处理股票：
#
# SH600725
#
#
# 正在处理股票： 正在处理股票：正在处理股票：正在处理股票：SH601888
# SH600376SH600582正在处理股票：
#
#
#  正在处理股票：正在处理股票：SH600571正在处理股票：
#    SH600704SH601881SH600908
#
#
# 正在处理股票：正在处理股票：正在处理股票：正在处理股票：   SH601229SH600383SH600728SH601689
#
#
# 正在处理股票：SH600886
# 正在处理股票：正在处理股票：正在处理股票：  正在处理股票：SH603636
# 正在处理股票：SH600177SH603316
#
#
# 正在处理股票： SH603825SH600999SH600176正在处理股票：正在处理股票：
#
# 正在处理股票：  正在处理股票：SH600309 SH600900
# SH600406正在处理股票：SH603626
#
#
# SH601066正在处理股票：SH688538
#
#  SH688009正在处理股票：SH600837
#
#
# 正在处理股票：SH603323正在处理股票：  正在处理股票：
# SH601989 SH601728
#
# SH601390正在处理股票：
# 正在处理股票：正在处理股票：正在处理股票： 正在处理股票：正在处理股票：正在处理股票：正在处理股票：    SH601608 SH600823SH600839SH600863
#  SH601106
#
#
# SH600979正在处理股票：SH601186
#  正在处理股票： 正在处理股票：正在处理股票： SH600686 SH600675
# SH600653
# 正在处理股票：
#
# 正在处理股票：SH600790 正在处理股票：
#
# SH600512  正在处理股票：
# SH600337正在处理股票： 正在处理股票：正在处理股票：
# SH600518 SH600269
# SH600380正在处理股票：
# SH600390正在处理股票： SH600400
# 正在处理股票：
# SH600252
# 正在处理股票： 正在处理股票：
# 正在处理股票：SH600208SH600282
#
#  正在处理股票：   正在处理股票：正在处理股票：SH600179 SH600190
# SH600050
# SH600031SH600153
# 正在处理股票：
# SH600166 正在处理股票：
# 正在处理股票：
#  正在处理股票：SH600200SH600075 正在处理股票：
# SH600867
# SH600875正在处理股票：
#
# 正在处理股票：正在处理股票：正在处理股票：正在处理股票：  SH600028正在处理股票： SH601997
# SH601231SH601615SH600061
#
# SH600997
# SH600860正在处理股票：
# 正在处理股票：
#
# SH600203 正在处理股票：SH600125 正在处理股票：
# 正在处理股票：SH688306正在处理股票： 正在处理股票：
#  正在处理股票：SH600039 SH601766
#
#  正在处理股票：SH600217正在处理股票：
# 正在处理股票：  SH603183SH601179 SH688327
#
#
# SH601857正在处理股票：
# SH600079 正在处理股票：
# 正在处理股票：  正在处理股票：SH600727SH600368 正在处理股票：SH603259正在处理股票：
#
#
#  正在处理股票： SH601727
# SH605196 正在处理股票：SH600366SH600597
#
# SH600545正在处理股票：正在处理股票：
#
# 正在处理股票：正在处理股票：正在处理股票：
#   正在处理股票：SH600067SH600928SH601567SH600151
#
#
#
#  正在处理股票：SH600507
# SH601908SH600874
#
# 正在处理股票：正在处理股票： 正在处理股票：正在处理股票：正在处理股票：SH600853正在处理股票：SH600408
#
#    正在处理股票：正在处理股票：正在处理股票：SH600336 SH601901
#  SH600232
# SH600794SH600008SH601010正在处理股票：
#
#
# SH600958 SH601326
#
# 正在处理股票：正在处理股票：正在处理股票：SH601187
# SH600064SH600467
#
#
# 正在处理股票： 正在处理股票：正在处理股票：正在处理股票：正在处理股票：正在处理股票：正在处理股票：    SH601665SH600073SH600284
#
#
#  SH601108正在处理股票：SH600126正在处理股票：
#
#
# SH600703 SH603507SH600887
#  SH601360正在处理股票：
# 正在处理股票：正在处理股票：正在处理股票：SH601000正在处理股票：正在处理股票： SH600029
#
#  SH600789正在处理股票：
# SH600100 正在处理股票：SH600716
# SH600816SH601375正在处理股票：
#
#
#  正在处理股票：SH603619
#  正在处理股票：SH601636正在处理股票：SH603035 正在处理股票：
#
# 正在处理股票：  SH600522
# 正在处理股票： SH600433
#  正在处理股票： SH600584正在处理股票： 正在处理股票：SH600528正在处理股票：
#   SH600741SH600360正在处理股票：
#
#
#  SH600223SH601598SH600416
# 正在处理股票：正在处理股票： 正在处理股票：
# 正在处理股票：SH600059
#  正在处理股票：
# 正在处理股票： SH600967SH600483
#
# SH600517
# SH600248SH600838 SH600982
#
#
# SH600804
# 正在处理股票： SH600585
# 正在处理股票：正在处理股票： 正在处理股票： SH601618正在处理股票： 正在处理股票：SH600063 SH600403 SH601226
#
# SH600320
#
#
# 正在处理股票： SH600621
# 正在处理股票：正在处理股票：正在处理股票：正在处理股票： 正在处理股票： 正在处理股票：正在处理股票：正在处理股票：   SH600141SH600312
# SH601162SH600575SH600348SH600035
#
#
# SH600340
#
# 正在处理股票： 正在处理股票：SH600640
#
# SH603633正在处理股票：正在处理股票：
#   正在处理股票： SH601866SH600985SH600906正在处理股票：正在处理股票：
#
#  正在处理股票：
#
# SH601198 SH600971
# SH601996
# 正在处理股票：SH600395 正在处理股票：SH600630
# 正在处理股票： 正在处理股票：
# SH600583
# 正在处理股票： SH600077
# 正在处理股票：正在处理股票： 正在处理股票： 正在处理股票：正在处理股票：SH601555 SH600104
# 正在处理股票： SH600691  SH600792
# SH600595
# 正在处理股票：正在处理股票：
# SH601018
# SH601877SH603218正在处理股票：
#
#
#  正在处理股票：  SH600968SH600206
# 正在处理股票：
# SH600478SH600755
# SH603011
# SH600352
#
# 正在处理股票： 正在处理股票：正在处理股票：正在处理股票：  正在处理股票：正在处理股票：SH600057SH600169
#
# 正在处理股票： 正在处理股票：正在处理股票：  正在处理股票：SH600199SH600777SH601111
#
#    正在处理股票：
# SH603158正在处理股票：正在处理股票：SH600103 正在处理股票：SH600667SH688126 SH600310
#
#
# 正在处理股票：正在处理股票：正在处理股票：
#    SH601717SH600742SH600158
# SH603598
# SH600487SH600995
# 正在处理股票：正在处理股票：
#
#   正在处理股票：SH605358SH600572
#
#
# 正在处理股票：正在处理股票： SH600594SH601828
# 正在处理股票：
#
# 正在处理股票：正在处理股票：正在处理股票： 正在处理股票： 正在处理股票： SH600916正在处理股票：正在处理股票：SH603077SH601696
#  正在处理股票：SH601528SH603876SH600260正在处理股票：
#
#
# 正在处理股票：SH600438SH603799
#
# SH601600
#
#  SH600489
# 正在处理股票：正在处理股票：
# 正在处理股票：正在处理股票： 正在处理股票： 正在处理股票：正在处理股票：SH600771 SH600293 SH601168
# SH688779 正在处理股票：
# 正在处理股票：
# SH600257 SH600787正在处理股票：SH601952
#  SH600872 正在处理股票：
#
#
# 正在处理股票：SH600238正在处理股票：正在处理股票：
#   SH603906SH603589
# SH600598 SH601007
#
#
#
# SH600841
# 正在处理股票： 正在处理股票：正在处理股票： 正在处理股票：SH600988正在处理股票：正在处理股票：  SH601519SH603538
#
#
#
# 正在处理股票： SH600218正在处理股票：
# 正在处理股票：SH600143
#  SH600331正在处理股票： SH600862SH600811SH600130
#
# SH600516
#
# 正在处理股票：正在处理股票：  SH601238SH600422正在处理股票：
#
# 正在处理股票：正在处理股票：正在处理股票：正在处理股票：正在处理股票： 正在处理股票：正在处理股票： SH603806  SH603766
# SH600186SH600732
#
#
# SH600805
#  SH600699
# SH600150SH603936
#
# SH603986正在处理股票： SH600587
# 正在处理股票：
# 正在处理股票：正在处理股票：正在处理股票：
# 正在处理股票：正在处理股票：正在处理股票：正在处理股票：正在处理股票：
#     SH600110SH601388  SH600490SH601702SH600405
#
# SH600370SH600160SH603169
#
#
# 正在处理股票：正在处理股票：
# 正在处理股票：正在处理股票：正在处理股票：正在处理股票： 正在处理股票：正在处理股票：SH600609  SH600192SH600435
#
# 正在处理股票： SH600477
#  SH600210
# 正在处理股票：    SH600267SH600072
# SH600470
# 正在处理股票：
# SH601700正在处理股票：
#  SH600969 SH600935
# 正在处理股票：SH603166正在处理股票：
#  SH601236
#
# 正在处理股票：
# 正在处理股票： 正在处理股票：SH600497正在处理股票：正在处理股票：  SH600759 SH600006SH600586
#
#
#  正在处理股票：正在处理股票：
# 正在处理股票： 正在处理股票： 正在处理股票：SH600662  正在处理股票：SH600237SH603501
#
# SH600618SH600903 SH603227
# SH600458
# 正在处理股票：
#
# 正在处理股票：
# 正在处理股票： SH600362 SH600746正在处理股票：正在处理股票：
# 正在处理股票：SH603659
#
# 正在处理股票：正在处理股票：  正在处理股票：SH600108 正在处理股票：SH601677SH601218SH600116SH600101 SH688660
#
#
#
#
# SH603803正在处理股票：正在处理股票： 正在处理股票：正在处理股票： SH601137 SH600480
#
#
# 正在处理股票：SH603678 SH603335正在处理股票：
# SH603027 正在处理股票：
#
# 正在处理股票：正在处理股票：正在处理股票：
#   SH600960SH600624SH600081
#
#
# SH601606正在处理股票：正在处理股票：SH600330
# 正在处理股票：正在处理股票：正在处理股票：正在处理股票：SH600513
#   SH600156
# SH600121SH600268
#
#    SH600085SH600730
# SH600386
#
#
# 正在处理股票：正在处理股票：正在处理股票：正在处理股票：正在处理股票：正在处理股票：   正在处理股票： 正在处理股票：  SH600197SH600491 SH600884SH600989
#
#
# 正在处理股票：正在处理股票：  SH600354 SH601126SH600233
# SH601969正在处理股票：SH603815
# SH601579
# 正在处理股票：
#
# 正在处理股票：
#   SH600521
# SH601069正在处理股票：正在处理股票：
# 正在处理股票：正在处理股票：正在处理股票：
# SH600202正在处理股票： 正在处理股票：SH600213
# SH600328    正在处理股票：
# SH600418正在处理股票：
#
# SH601233 SH600371SH601311SH600409正在处理股票：SH600078
#
#
# 正在处理股票：
#   正在处理股票：正在处理股票：SH601279
# SH600469正在处理股票：正在处理股票：
# SH601020
# SH600098
# 正在处理股票：
#   正在处理股票： 正在处理股票：SH603128
#
# SH600479SH600711
# SH600893
# SH600866 SH601966正在处理股票：正在处理股票：
#
#  正在处理股票：正在处理股票：SH603215正在处理股票：正在处理股票：正在处理股票：  正在处理股票：SH600495    SH688303SH600844
# SH603018
#
# SH600375SH600596
# 正在处理股票： SH600765正在处理股票：  SH600975SH600220
#
# 正在处理股票：正在处理股票：
#
#  SH600259SH600551
#
# 正在处理股票： SH600616
#
#
# 正在处理股票： SH601777
# 加载历史数据: 99%:  ▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋正在初始化:  SZ300479
# 正在初始化:  SZ300024
# 正在初始化:  SZ300293
# 正在初始化:  SZ300891
# 正在初始化:  SZ300585
# 正在初始化:  SZ300657
# 正在初始化:  SZ300400
# 正在初始化:  SZ002482
# 正在初始化:  SZ002031
# 正在初始化:  SZ000068
# 正在初始化:  SZ000589
# 正在初始化:  SZ002527
# 正在初始化:  SZ002559
# 正在初始化:  SZ002703
# 正在初始化:  SZ002047
# 正在初始化:  SZ000037
# 正在初始化:  SZ002174
# 正在初始化:  SZ002909
# 正在初始化:  SZ002848
# 正在初始化:  SZ002638
# 正在初始化:  SZ002380
# 正在初始化:  SZ002347
# 正在初始化:  SZ000702
# 正在初始化:  SZ000403
# 正在初始化:  SZ000020
# 正在初始化:  SZ002988
# 正在初始化:  SZ002657
# 正在初始化:  SZ002403
# 正在初始化:  SZ000880
# 正在初始化:  SZ000627
# 正在初始化:  SZ002587
# 正在初始化:  SZ002204
# 正在初始化:  SZ300278
# 正在初始化:  SZ300742
# 正在初始化:  SZ300468
# 正在初始化:  SZ002918
# 正在初始化:  SZ300607
# 正在初始化:  SZ002613
# 正在初始化:  SZ000584
# 正在初始化:  SZ300097
# 正在初始化:  SZ300793
# 正在初始化:  SZ300626
# 正在初始化:  SZ300250
# 正在初始化:  SZ002892
# 正在初始化:  SZ002996
# 正在初始化:  SZ300486
# 正在初始化:  SZ000821
# 正在初始化:  SZ002581
# 正在初始化:  SZ300565
# 正在初始化:  SZ300058
# 正在初始化:  SZ300044
# 正在初始化:  SZ002605
# 正在初始化:  SZ300556
# 正在初始化:  SZ000810
# 正在初始化:  SZ000029
# 正在初始化:  SZ002208
# 正在初始化:  SZ000925
# 正在初始化:  SZ002343
# 正在初始化:  SZ300466
# 正在初始化:  SZ002197
# 正在初始化:  SZ002417
# 正在初始化:  SZ002314
# 正在初始化:  SZ300612
# 正在初始化:  SZ000525
# 正在初始化:  SZ000736
# 正在初始化:  SZ300112
# 正在初始化:  SZ002761
# 正在初始化:  SZ300546
# 正在初始化:  SZ002244
# 正在初始化:  SZ300166
# 正在初始化:  SZ002775
# 正在初始化:  SZ002635
# 正在初始化:  SZ300110
# 正在初始化:  SZ002292
# 正在初始化:  SZ300081
# 正在初始化:  SZ002685
# 正在初始化:  SZ300050
# 正在初始化:  SZ300117
# 正在初始化:  SZ300459
# 正在初始化:  SZ002866
# 正在初始化:  SZ300543
# 正在初始化:  SZ002445
# 正在初始化:  SZ300438
# 正在初始化:  SZ300541
# 正在初始化:  SZ300173
# 正在初始化:  SZ000665
# 正在初始化:  SZ002384
# 正在初始化:  SZ002168
# 正在初始化:  SZ000503
# 正在初始化:  SZ300276
# 正在初始化:  SZ000681
# 正在初始化:  SZ300360
# 正在初始化:  SZ002747
# 正在初始化:  SZ000767
# 正在初始化:  SZ000514
# 正在初始化:  SZ300249
# 正在初始化:  SZ300307
# 正在初始化:  SZ002241
# 正在初始化:  SZ002689
# 正在初始化:  SZ000517
# 正在初始化:  SZ000055
# 正在初始化:  SZ000918
# 正在初始化:  SZ000999
# 正在初始化:  SZ002647
# 正在初始化:  SZ002415
# 正在初始化:  SZ000837
# 正在初始化:  SZ000799
# 正在初始化:  SZ300181
# 正在初始化:  SZ300167
# 正在初始化:  SZ002774
# 正在初始化:  SZ300113
# 正在初始化:  SZ200761
# 正在初始化:  SZ002753
# 正在初始化:  SZ002309
# 正在初始化:  SZ002043
# 正在初始化:  SZ002152
# 正在初始化:  SZ300579
# 正在初始化:  SZ002938
# 正在初始化:  SZ002526
# 正在初始化:  SZ002133
# 正在初始化:  SZ000609
# 正在初始化:  SZ002045
# 正在初始化:  SZ002652
# 正在初始化:  SZ300264
# 正在初始化:  SZ000017
# 正在初始化:  SZ300420
# 正在初始化:  SZ300188
# 正在初始化:  SZ002083
# 正在初始化:  SZ300344
# 正在初始化:  SZ300735
# 正在初始化:  SZ300551
# 正在初始化:  SZ300225
# 正在初始化:  SZ000537
# 正在初始化:  SZ000532
# 正在初始化:  SZ000756
# 正在初始化:  SZ300366
# 正在初始化:  SZ002223
# 正在初始化:  SZ300433
# 正在初始化:  SZ300561
# 正在初始化:  SZ002184
# 正在初始化:  SZ300494
# 正在初始化:  SZ000570
# 正在初始化:  SZ002589
# 正在初始化:  SZ300221
# 正在初始化:  SZ000809
# 正在初始化:  SZ300025
# 正在初始化:  SZ300464
# 正在初始化:  SZ300386
# 正在初始化:  SZ300353
# 正在初始化:  SZ300133
# 正在初始化:  SZ000690
# 正在初始化:  SZ002995
# 正在初始化:  SZ000957
# 正在初始化:  SZ002475
# 正在初始化:  SZ300043
# 正在初始化:  SZ002686
# 正在初始化:  SZ000716
# 正在初始化:  SZ002789
# 正在初始化:  SZ000548
# 正在初始化:  SZ300031
# 正在初始化:  SZ002348
# 正在初始化:  SZ300663
# 正在初始化:  SZ002713
# 正在初始化:  SZ000766
# 正在初始化:  SZ000726
# 正在初始化:  SZ000678
# 正在初始化:  SZ300085
# 正在初始化:  SZ000720
# 正在初始化:  SZ003040
# 正在初始化:  SZ002572
# 正在初始化:  SZ300846
# 正在初始化:  SZ002955
# 正在初始化:  SZ300303
# 正在初始化:  SZ300232
# 正在初始化:  SZ000430
# 正在初始化:  SZ002219
# 正在初始化:  SZ300588
# 正在初始化:  SZ300131
# 正在初始化:  SZ300026
# 正在初始化:  SZ000917
# 正在初始化:  SZ002178
# 正在初始化:  SZ000529
# 正在初始化:  SZ002024
# 正在初始化:  SZ000708
# 正在初始化:  SZ300012
# 正在初始化:  SZ000545
# 正在初始化:  SZ300130
# 正在初始化:  SZ002534
# 正在初始化:  SZ300498
# 正在初始化:  SZ300707
# 正在初始化:  SZ300047
# 正在初始化:  SZ000793
# 正在初始化:  SZ002382
# 正在初始化:  SZ002248
# 正在初始化:  SZ000014
# 正在初始化:  SZ002558
# 正在初始化:  SZ002502
# 正在初始化:  SZ300242
# 正在初始化:  SZ002016
# 正在初始化:  SZ300134
# 正在初始化:  SZ002620
# 正在初始化:  SZ000400
# 正在初始化:  SZ300061
# 正在初始化:  SZ300773
# 正在初始化:  SZ002456
# 正在初始化:  SZ300831
# 正在初始化:  SZ300083
# 正在初始化:  SZ002971
# 正在初始化:  SZ002530
# 正在初始化:  SZ300008
# 正在初始化:  SZ300020
# 正在初始化:  SZ002642
# 正在初始化:  SZ000543
# 正在初始化:  SZ002883
# 正在初始化:  SZ002585
# 正在初始化:  SZ000632
# 正在初始化:  SZ002305
# 正在初始化:  SZ002463
# 正在初始化:  SZ002051
# 正在初始化:  SZ000757
# 正在初始化:  SZ002158
# 正在初始化:  SZ000607
# 正在初始化:  SZ300295
# 正在初始化:  SZ000560
# 正在初始化:  SZ300182
# 正在初始化:  SZ002390
# 正在初始化:  SZ002367
# 正在初始化:  SZ300079
# 正在初始化:  SZ002639
# 正在初始化:  SZ300291
# 正在初始化:  SZ002344
# 正在初始化:  SZ002103
# 正在初始化:  SZ000859
# 正在初始化:  SZ000677
# 正在初始化:  SZ002377
# 正在初始化:  SZ300248
# 正在初始化:  SZ000652
# 正在初始化:  SZ300465
# 正在初始化:  SZ002221
# 正在初始化:  SZ000555
# 正在初始化:  SZ002235
# 正在初始化:  SZ300311
# 正在初始化:  SZ300408
# 正在初始化:  SZ300603
# 正在初始化:  SZ300170
# 正在初始化:  SZ000965
# 正在初始化:  SZ002699
# 正在初始化:  SZ002528
# 正在初始化:  SZ000423
# 正在初始化:  SZ300647
# 正在初始化:  SZ300304
# 正在初始化:  SZ300256
# 正在初始化:  SZ002123
# 正在初始化:  SZ300348
# 正在初始化:  SZ002099
# 正在初始化:  SZ002020
# 正在初始化:  SZ300017
# 正在初始化:  SZ300241
# 正在初始化:  SZ002372
# 正在初始化:  SZ002145
# 正在初始化:  SZ300194
# 正在初始化:  SZ002628
# 正在初始化:  SZ002602
# 正在初始化:  SZ300738
# 正在初始化:  SZ300075
# 正在初始化:  SZ000951
# 正在初始化:  SZ300180
# 正在初始化:  SZ000608
# 正在初始化:  SZ000012
# 正在初始化:  SZ300144
# 正在初始化:  SZ300300
# 正在初始化:  SZ000040
# 正在初始化:  SZ000573
# 正在初始化:  SZ300165
# 正在初始化:  SZ000863
# 正在初始化:  SZ300418
# 正在初始化:  SZ300086
# 正在初始化:  SZ000786
# 正在初始化:  SZ000006
# 正在初始化:  SZ002345
# 正在初始化:  SZ000721
# 正在初始化:  SZ002302
# 正在初始化:  SZ300213
# 正在初始化:  SZ002554
# 正在初始化:  SZ002195
# 正在初始化:  SZ300315
# 正在初始化:  SZ002307
# 正在初始化:  SZ300292
# 正在初始化:  SZ300476
# 正在初始化:  SZ000909
# 正在初始化:  SZ002537
# 正在初始化:  SZ300197
# 正在初始化:  SZ300272
# 正在初始化:  SZ000987
# 正在初始化:  SZ002723
# 正在初始化:  SZ002137
# 正在初始化:  SZ300115
# 正在初始化:  SZ000717
# 正在初始化:  SZ000420
# 正在初始化:  SZ300266
# 正在初始化:  SZ001914
# 正在初始化:  SZ300027
# 正在初始化:  SZ002062
# 正在初始化:  SZ002733
# 正在初始化:  SZ300136
# 正在初始化:  SZ002489
# 正在初始化:  SZ003816
# 正在初始化:  SZ002517
# 正在初始化:  SZ300229
# 正在初始化:  SZ300310
# 正在初始化:  SZ300271
# 正在初始化:  SZ300251
# 正在初始化:  SZ002211
# 正在初始化:  SZ300036
# 正在初始化:  SZ002162
# 正在初始化:  SZ002717
# 正在初始化:  SZ000651
# 正在初始化:  SZ002405
# 正在初始化:  SZ002512
# 正在初始化:  SZ300071
# 正在初始化:  SZ002230
# 正在初始化:  SZ000563
# 正在初始化:  SZ000905
# 正在初始化:  SZ002600
# 正在初始化:  SZ002236
# 正在初始化:  SZ300441
# 正在初始化:  SZ002431
# 正在初始化:  SZ000908
# 正在初始化:  SZ002081
# 正在初始化:  SZ000898
# 正在初始化:  SZ300007
# 正在初始化:  SZ002822
# 正在初始化:  SZ002701
# 正在初始化:  SZ002288
# 正在初始化:  SZ300377
# 正在初始化:  SZ000661
# 正在初始化:  SZ000416
# 正在初始化:  SZ002273
# 正在初始化:  SZ300018
# 正在初始化:  SZ300063
# 正在初始化:  SZ300287
# 正在初始化:  SZ002065
# 正在初始化:  SZ002369
# 正在初始化:  SZ300370
# 正在初始化:  SZ000997
# 正在初始化:  SZ002027
# 正在初始化:  SZ000415
# 正在初始化:  SZ000703
# 正在初始化:  SZ002181
# 正在初始化:  SZ000566
# 正在初始化:  SZ000090
# 正在初始化:  SZ002033
# 正在初始化:  SZ002310
# 正在初始化:  SZ002177
# 正在初始化:  SZ000926
# 正在初始化:  SZ002075
# 正在初始化:  SZ000921
# 正在初始化:  SZ002038
# 正在初始化:  SZ002437
# 正在初始化:  SZ000333
# 正在初始化:  SZ300009
# 正在初始化:  SZ000722
# 正在初始化:  SZ002736
# 正在初始化:  SZ002839
# 正在初始化:  SZ300145
# 正在初始化:  SZ002936
# 正在初始化:  SZ300124
# 正在初始化:  SZ000676
# 正在初始化:  SZ300306
# 正在初始化:  SZ002542
# 正在初始化:  SZ000558
# 正在初始化:  SZ002128
# 正在初始化:  SZ002474
# 正在初始化:  SZ002421
# 正在初始化:  SZ002130
# 正在初始化:  SZ002622
# 正在初始化:  SZ000011
# 正在初始化:  SZ002285
# 正在初始化:  SZ002142
# 正在初始化:  SZ300102
# 正在初始化:  SZ002548
# 正在初始化:  SZ002396
# 正在初始化:  SZ300803
# 正在初始化:  SZ002104
# 正在初始化:  SZ300290
# 正在初始化:  SZ002373
# 正在初始化:  SZ000923
# 正在初始化:  SZ000001
# 正在初始化:  SZ000932
# 正在初始化:  SZ000968
# 正在初始化:  SZ002044
# 正在初始化:  SZ002468
# 正在初始化:  SZ000899
# 正在初始化:  SZ002966
# 正在初始化:  SZ000507
# 正在初始化:  SZ000089
# 正在初始化:  SZ002608
# 正在初始化:  SZ002601
# 正在初始化:  SZ000686
# 正在初始化:  SZ300120
# 正在初始化:  SZ002363
# 正在初始化:  SZ300943
# 正在初始化:  SZ002078
# 正在初始化:  SZ002271
# 正在初始化:  SZ300375
# 正在初始化:  SZ300355
# 正在初始化:  SZ300296
# 正在初始化:  SZ300267
# 正在初始化:  SZ300237
# 正在初始化:  SZ300128
# 正在初始化:  SZ300111
# 正在初始化:  SZ300003
# 正在初始化:  SZ002948
# 正在初始化:  SZ002627
# 正在初始化:  SZ002551
# 正在初始化:  SZ002471
# 正在初始化:  SZ002433
# 正在初始化:  SZ002267
# 正在初始化:  SZ002251
# 正在初始化:  SZ002154
# 正在初始化:  SZ000959
# 正在初始化:  SZ000950
# 正在初始化:  SZ000937
# 正在初始化:  SZ000928
# 正在初始化:  SZ000927
# 正在初始化:  SZ000725
# 正在初始化:  SZ000718
# 正在初始化:  SZ000709
# 正在初始化:  SZ000656
# 正在初始化:  SZ000592
# 正在初始化:  SZ000552
# 正在初始化:  SZ000100
# 正在初始化:  SZ000069
# 正在初始化:  SH600149
# 正在初始化:  SH600996
# 正在初始化:  SH603530
# 正在初始化:  SH600657
# 正在初始化:  SH600992
# 正在初始化:  SH603960
# 正在初始化:  SH603728
# 正在初始化:  SH603717
# 正在初始化:  SH600665
# 正在初始化:  SH600335
# 正在初始化:  SH600668
# 正在初始化:  SH600396
# 正在初始化:  SH603915
# 正在初始化:  SH603918
# 正在初始化:  SH600965
# 正在初始化:  SH600633
# 正在初始化:  SH600936
# 正在初始化:  SH600010
# 正在初始化:  SH600987
# 正在初始化:  SH601216
# 正在初始化:  SH600706
# 正在初始化:  SH601929
# 正在初始化:  SH600570
# 正在初始化:  SH600610
# 正在初始化:  SH603693
# 正在初始化:  SH603920
# 正在初始化:  SH600256
# 正在初始化:  SH600026
# 正在初始化:  SH601886
# 正在初始化:  SH600783
# 正在初始化:  SH600795
# 正在初始化:  SH603603
# 正在初始化:  SH600128
# 正在初始化:  SH603085
# 正在初始化:  SH603009
# 正在初始化:  SH603466
# 正在初始化:  SH600227
# 正在初始化:  SH600139
# 正在初始化:  SH600322
# 正在初始化:  SH601628
# 正在初始化:  SH600499
# 正在初始化:  SH600756
# 正在初始化:  SH600027
# 正在初始化:  SH600212
# 正在初始化:  SH600926
# 正在初始化:  SH603103
# 正在初始化:  SH600106
# 正在初始化:  SH600325
# 正在初始化:  SH600011
# 正在初始化:  SH600581
# 正在初始化:  SH601319
# 正在初始化:  SH603985
# 正在初始化:  SH601872
# 正在初始化:  SH600986
# 正在初始化:  SH603881
# 正在初始化:  SH600353
# 正在初始化:  SH603066
# 正在初始化:  SH600793
# 正在初始化:  SH600037
# 正在初始化:  SH603396
# 正在初始化:  SH600736
# 正在初始化:  SH601599
# 正在初始化:  SH601658
# 正在初始化:  SH600733
# 正在初始化:  SH600155
# 正在初始化:  SH603108
# 正在初始化:  SH600959
# 正在初始化:  SH600538
# 正在初始化:  SH600726
# 正在初始化:  SH600831
# 正在初始化:  SH600025
# 正在初始化:  SH600094
# 正在初始化:  SH605388
# 正在初始化:  SH600159
# 正在初始化:  SH601838
# 正在初始化:  SH600231
# 正在初始化:  SH600135
# 正在初始化:  SH600713
# 正在初始化:  SH600533
# 正在初始化:  SH600535
# 正在初始化:  SH601688
# 正在初始化:  SH600546
# 正在初始化:  SH600138
# 正在初始化:  SH600702
# 正在初始化:  SH600496
# 正在初始化:  SH600201
# 正在初始化:  SH601336
# 正在初始化:  SH603378
# 正在初始化:  SH601225
# 正在初始化:  SH600801
# 正在初始化:  SH600082
# 正在初始化:  SH600502
# 正在初始化:  SH600622
# 正在初始化:  SH601318
# 正在初始化:  SH603030
# 正在初始化:  SH603390
# 正在初始化:  SH601800
# 正在初始化:  SH603078
# 正在初始化:  SH601985
# 正在初始化:  SH603938
# 正在初始化:  SH600327
# 正在初始化:  SH601228
# 正在初始化:  SH600036
# 正在初始化:  SH603225
# 正在初始化:  SH600639
# 正在初始化:  SH600881
# 正在初始化:  SH600693
# 正在初始化:  SH601601
# 正在初始化:  SH601816
# 正在初始化:  SH603429
# 正在初始化:  SH603123
# 正在初始化:  SH600678
# 正在初始化:  SH601992
# 正在初始化:  SH600162
# 正在初始化:  SH600527
# 正在初始化:  SH600030
# 正在初始化:  SH600071
# 正在初始化:  SH600196
# 正在初始化:  SH601878
# 正在初始化:  SH600919
# 正在初始化:  SH600664
# 正在初始化:  SH601898
# 正在初始化:  SH600373
# 正在初始化:  SH601009
# 正在初始化:  SH600880
# 正在初始化:  SH600048
# 正在初始化:  SH601166
# 正在初始化:  SH688599
# 正在初始化:  SH601398
# 正在初始化:  SH600188
# 正在初始化:  SH600690
# 正在初始化:  SH600708
# 正在初始化:  SH600797
# 正在初始化:  SH603555
# 正在初始化:  SH600509
# 正在初始化:  SH600243
# 正在初始化:  SH603115
# 正在初始化:  SH600569
# 正在初始化:  SH600297
# 正在初始化:  SH600637
# 正在初始化:  SH600590
# 正在初始化:  SH601668
# 正在初始化:  SH603843
# 正在初始化:  SH600683
# 正在初始化:  SH600773
# 正在初始化:  SH603366
# 正在初始化:  SH600684
# 正在初始化:  SH601199
# 正在初始化:  SH600503
# 正在初始化:  SH601328
# 正在初始化:  SH600123
# 正在初始化:  SH600452
# 正在初始化:  SH600185
# 正在初始化:  SH601818
# 正在初始化:  SH600510
# 正在初始化:  SH600578
# 正在初始化:  SH601988
# 正在初始化:  SH603023
# 正在初始化:  SH600235
# 正在初始化:  SH600715
# 正在初始化:  SH601916
# 正在初始化:  SH600641
# 正在初始化:  SH600565
# 正在初始化:  SH600603
# 正在初始化:  SH600096
# 正在初始化:  SH601788
# 正在初始化:  SH600556
# 正在初始化:  SH600901
# 正在初始化:  SH601001
# 正在初始化:  SH600770
# 正在初始化:  SH600000
# 正在初始化:  SH605111
# 正在初始化:  SH600836
# 正在初始化:  SH600439
# 正在初始化:  SH600372
# 正在初始化:  SH603648
# 正在初始化:  SH601003
# 正在初始化:  SH600973
# 正在初始化:  SH600642
# 正在初始化:  SH600740
# 正在初始化:  SH600355
# 正在初始化:  SH600557
# 正在初始化:  SH600133
# 正在初始化:  SH601939
# 正在初始化:  SH601169
# 正在初始化:  SH600109
# 正在初始化:  SH601101
# 正在初始化:  SH600170
# 正在初始化:  SH600052
# 正在初始化:  SH601808
# 正在初始化:  SH601718
# 正在初始化:  SH600617
# 正在初始化:  SH600055
# 正在初始化:  SH600295
# 正在初始化:  SH600619
# 正在初始化:  SH600602
# 正在初始化:  SH600015
# 正在初始化:  SH600446
# 正在初始化:  SH600782
# 正在初始化:  SH600300
# 正在初始化:  SH600705
# 正在初始化:  SH600023
# 正在初始化:  SH600398
# 正在初始化:  SH601699
# 正在初始化:  SH600748
# 正在初始化:  SH600808
# 正在初始化:  SH600448
# 正在初始化:  SH600559
# 正在初始化:  SH600606
# 正在初始化:  SH601077
# 正在初始化:  SH600859
# 正在初始化:  SH600604
# 正在初始化:  SH600120
# 正在初始化:  SH603333
# 正在初始化:  SH600369
# 正在初始化:  SH601607
# 正在初始化:  SH600009
# 正在初始化:  SH600905
# 正在初始化:  SH600649
# 正在初始化:  SH601211
# 正在初始化:  SH600791
# 正在初始化:  SH601088
# 正在初始化:  SH600753
# 正在初始化:  SH601588
# 正在初始化:  SH600707
# 正在初始化:  SH601998
# 正在初始化:  SH601118
# 正在初始化:  SH601918
# 正在初始化:  SH601991
# 正在初始化:  SH600864
# 正在初始化:  SH600021
# 正在初始化:  SH600751
# 正在初始化:  SH600718
# 正在初始化:  SH600567
# 正在初始化:  SH601860
# 正在初始化:  SH600410
# 正在初始化:  SH601789
# 正在初始化:  SH603398
# 正在初始化:  SH601099
# 正在初始化:  SH601288
# 正在初始化:  SH600720
# 正在初始化:  SH600868
# 正在初始化:  SH601138
# 正在初始化:  SH600515
# 正在初始化:  SH600635
# 正在初始化:  SH601006
# 正在初始化:  SH601012
# 正在初始化:  SH600397
# 正在初始化:  SH601975
# 正在初始化:  SH603399
# 正在初始化:  SH600016
# 正在初始化:  SH603363
# 正在初始化:  SH600266
# 正在初始化:  SH600717
# 正在初始化:  SH600725
# 正在初始化:  SH601008
# 正在初始化:  SH600425
# 正在初始化:  SH600183
# 正在初始化:  SH600758
# 正在初始化:  SH600939
# 正在初始化:  SH600184
# 正在初始化:  SH601888
# 正在初始化:  SH600571
# 正在初始化:  SH601881
# 正在初始化:  SH600376
# 正在初始化:  SH600582
# 正在初始化:  SH600704
# 正在初始化:  SH601689
# 正在初始化:  SH600886
# 正在初始化:  SH600908
# 正在初始化:  SH603636
# 正在初始化:  SH600383
# 正在初始化:  SH603316
# 正在初始化:  SH600728
# 正在初始化:  SH601229
# 正在初始化:  SH600177
# 正在初始化:  SH603825
# 正在初始化:  SH600999
# 正在初始化:  SH603626
# 正在初始化:  SH600176
# 正在初始化:  SH601066
# 正在初始化:  SH600309
# 正在初始化:  SH600837
# 正在初始化:  SH600900
# 正在初始化:  SH600406
# 正在初始化:  SH688538
# 正在初始化:  SH688009
# 正在初始化:  SH603323
# 正在初始化:  SH601989
# 正在初始化:  SH601608
# 正在初始化:  SH601390
# 正在初始化:  SH601186
# 正在初始化:  SH601106
# 正在初始化:  SH600979
# 正在初始化:  SH600863
# 正在初始化:  SH600839
# 正在初始化:  SH600823
# 正在初始化:  SH600790
# 正在初始化:  SH600686
# 正在初始化:  SH600675
# 正在初始化:  SH600653
# 正在初始化:  SH600518
# 正在初始化:  SH600512
# 正在初始化:  SH600400
# 正在初始化:  SH600390
# 正在初始化:  SH600380
# 正在初始化:  SH600337
# 正在初始化:  SH600282
# 正在初始化:  SH600269
# 正在初始化:  SH600252
# 正在初始化:  SH600208
# 正在初始化:  SH600200
# 正在初始化:  SH600190
# 正在初始化:  SH600179
# 正在初始化:  SH600166
# 正在初始化:  SH600153
# 正在初始化:  SH600075
# 正在初始化:  SH600050
# 正在初始化:  SH600031
# 正在初始化:  SH600028
# 正在初始化:  SH601615
# 正在初始化:  SH600875
# 正在初始化:  SH600867
# 正在初始化:  SH600997
# 正在初始化:  SH601231
# 正在初始化:  SH600203
# 正在初始化:  SH600061
# 正在初始化:  SH600860
# 正在初始化:  SH601997
# 正在初始化:  SH601857
# 正在初始化:  SH600125
# 正在初始化:  SH600039
# 正在初始化:  SH600217
# 正在初始化:  SH601766
# 正在初始化:  SH603183
# 正在初始化:  SH601179
# 正在初始化:  SH603259
# 正在初始化:  SH600079
# 正在初始化:  SH600727
# 正在初始化:  SH601727
# 正在初始化:  SH600368
# 正在初始化:  SH600597
# 正在初始化:  SH600366
# 正在初始化:  SH605196
# 正在初始化:  SH600545
# 正在初始化:  SH600067
# 正在初始化:  SH600928
# 正在初始化:  SH601567
# 正在初始化:  SH600151
# 正在初始化:  SH600507
# 正在初始化:  SH601908
# 正在初始化:  SH600408
# 正在初始化:  SH600874
# 正在初始化:  SH600336
# 正在初始化:  SH601901
# 正在初始化:  SH600853
# 正在初始化:  SH600958
# 正在初始化:  SH600794
# 正在初始化:  SH601187
# 正在初始化:  SH601010
# 正在初始化:  SH600232
# 正在初始化:  SH600008
# 正在初始化:  SH601326
# 正在初始化:  SH601360
# 正在初始化:  SH600064
# 正在初始化:  SH600467
# 正在初始化:  SH600126
# 正在初始化:  SH603507
# 正在初始化:  SH601000
# 正在初始化:  SH601108
# 正在初始化:  SH600073
# 正在初始化:  SH601665
# 正在初始化:  SH600284
# 正在初始化:  SH600887
# 正在初始化:  SH600716
# 正在初始化:  SH600703
# 正在初始化:  SH600029
# 正在初始化:  SH603619
# 正在初始化:  SH600789
# 正在初始化:  SH600100
# 正在初始化:  SH600816
# 正在初始化:  SH601375
# 正在初始化:  SH601636
# 正在初始化:  SH603035
# 正在初始化:  SH600528
# 正在初始化:  SH600584
# 正在初始化:  SH601598
# 正在初始化:  SH600416
# 正在初始化:  SH600223
# 正在初始化:  SH600522
# 正在初始化:  SH600248
# 正在初始化:  SH600433
# 正在初始化:  SH600741
# 正在初始化:  SH600360
# 正在初始化:  SH600059
# 正在初始化:  SH600838
# 正在初始化:  SH600804
# 正在初始化:  SH600483
# 正在初始化:  SH600967
# 正在初始化:  SH600982
# 正在初始化:  SH600517
# 正在初始化:  SH600585
# 正在初始化:  SH601618
# 正在初始化:  SH600063
# 正在初始化:  SH600403
# 正在初始化:  SH601226
# 正在初始化:  SH600320
# 正在初始化:  SH600621
# 正在初始化:  SH600575
# 正在初始化:  SH600340
# 正在初始化:  SH601162
# 正在初始化:  SH600035
# 正在初始化:  SH600141
# 正在初始化:  SH600348
# 正在初始化:  SH603633
# 正在初始化:  SH600312
# 正在初始化:  SH600640
# 正在初始化:  SH600985
# 正在初始化:  SH601866
# 正在初始化:  SH600906
# 正在初始化:  SH601996
# 正在初始化:  SH601198
# 正在初始化:  SH600971
# 正在初始化:  SH600395
# 正在初始化:  SH600630
# 正在初始化:  SH600583
# 正在初始化:  SH600792
# 正在初始化:  SH601555
# 正在初始化:  SH600691
# 正在初始化:  SH600104
# 正在初始化:  SH600077
# 正在初始化:  SH600595
# 正在初始化:  SH601877
# 正在初始化:  SH603218
# 正在初始化:  SH601018
# 正在初始化:  SH600206
# 正在初始化:  SH600755
# 正在初始化:  SH600968
# 正在初始化:  SH600352
# 正在初始化:  SH603011
# 正在初始化:  SH600478
# 正在初始化:  SH600777
# 正在初始化:  SH601111
# 正在初始化:  SH600199
# 正在初始化:  SH600169
# 正在初始化:  SH600057
# 正在初始化:  SH600103
# 正在初始化:  SH688126
# 正在初始化:  SH600667
# 正在初始化:  SH603158
# 正在初始化:  SH600310
# 正在初始化:  SH600487
# 正在初始化:  SH603598
# 正在初始化:  SH600742
# 正在初始化:  SH601717
# 正在初始化:  SH600158
# 正在初始化:  SH600995
# 正在初始化:  SH605358
# 正在初始化:  SH600572
# 正在初始化:  SH601828
# 正在初始化:  SH600594
# 正在初始化:  SH688180
# 正在初始化:  SH601666
# 正在初始化:  SH600095
# 正在初始化:  SH603668
# 正在初始化:  SH600688
# 正在初始化:  SH600588
# 正在初始化:  SH600226
# 正在初始化:  SH601990
# 正在初始化:  SH600780
# 正在初始化:  SH601611
# 正在初始化:  SH601339
# 正在初始化:  SH600136
# 正在初始化:  SH601377
# 正在初始化:  SH600820
# 正在初始化:  SH600066
# 正在初始化:  SH600236
# 正在初始化:  SH600339
# 正在初始化:  SH600460
# 正在初始化:  SH600812
# 正在初始化:  SH600918
# 正在初始化:  SH601456
# 正在初始化:  SH601117
# 正在初始化:  SH603993
# 正在初始化:  SH601128
# 正在初始化:  SH600807
# 正在初始化:  SH600500
# 正在初始化:  SH600537
# 正在初始化:  SH603105
# 正在初始化:  SH600305
# 正在初始化:  SH601515
# 正在初始化:  SH603005
# 正在初始化:  SH600909
# 正在初始化:  SH603063
# 正在初始化:  SH600745
# 正在初始化:  SH600105
# 正在初始化:  SH600879
# 正在初始化:  SH603616
# 正在初始化:  SH600580
# 正在初始化:  SH600415
# 正在初始化:  SH603069
# 正在初始化:  SH603358
# 正在初始化:  SH600198
# 正在初始化:  SH600963
# 正在初始化:  SH688981
# 正在初始化:  SH600004
# 正在初始化:  SH600531
# 正在初始化:  SH601015
# 正在初始化:  SH603357
# 正在初始化:  SH600089
# 正在初始化:  SH601619
# 正在初始化:  SH600525
# 正在初始化:  SH600929
# 正在初始化:  SH600172
# 正在初始化:  SH600127
# 正在初始化:  SH601933
# 正在初始化:  SH601399
# 正在初始化:  SH600798
# 正在初始化:  SH600827
# 正在初始化:  SH600530
# 正在初始化:  SH600019
# 正在初始化:  SH601222
# 正在初始化:  SH600869
# 正在初始化:  SH603019
# 正在初始化:  SH601155
# 正在初始化:  SH600017
# 正在初始化:  SH600171
# 正在初始化:  SH600358
# 正在初始化:  SH603330
# 正在初始化:  SH601368
# 正在初始化:  SH600824
# 正在初始化:  SH600426
# 正在初始化:  SH601333
# 正在初始化:  SH600744
# 正在初始化:  SH600276
# 正在初始化:  SH600038
# 正在初始化:  SH600195
# 正在初始化:  SH601011
# 正在初始化:  SH600660
# 正在初始化:  SH600278
# 正在初始化:  SH601016
# 正在初始化:  SH601995
# 正在初始化:  SH600115
# 正在初始化:  SH600428
# 正在初始化:  SH603998
# 正在初始化:  SH600750
# 正在初始化:  SH601919
# 正在初始化:  SH600346
# 正在初始化:  SH601678
# 正在初始化:  SH600018
# 正在初始化:  SH600056
# 正在初始化:  SH600180
# 正在初始化:  SH600032
# 正在初始化:  SH600163
# 正在初始化:  SH603336
# 正在初始化:  SH600651
# 正在初始化:  SH601633
# 正在初始化:  SH601127
# 正在初始化:  SH601669
# 正在初始化:  SH601778
# 正在初始化:  SH600273
# 正在初始化:  SH600821
# 正在初始化:  SH603969
# 正在初始化:  SH600547
# 正在初始化:  SH600737
# 正在初始化:  SH603222
# 正在初始化:  SH600550
# 正在初始化:  SH603606
# 正在初始化:  SH600219
# 正在初始化:  SH601899
# 正在初始化:  SH600216
# 正在初始化:  SH600623
# 正在初始化:  SH601208
# 正在初始化:  SH603138
# 正在初始化:  SH600810
# 正在初始化:  SH600508
# 正在初始化:  SH603778
# 正在初始化:  SH601212
# 正在初始化:  SH601696
# 正在初始化:  SH600916
# 正在初始化:  SH603077
# 正在初始化:  SH600260
# 正在初始化:  SH600438
# 正在初始化:  SH603799
# 正在初始化:  SH601528
# 正在初始化:  SH603876
# 正在初始化:  SH600489
# 正在初始化:  SH601600
# 正在初始化:  SH600771
# 正在初始化:  SH688779
# 正在初始化:  SH601168
# 正在初始化:  SH600787
# 正在初始化:  SH600293
# 正在初始化:  SH600257
# 正在初始化:  SH600872
# 正在初始化:  SH601952
# 正在初始化:  SH600238
# 正在初始化:  SH603589
# 正在初始化:  SH600841
# 正在初始化:  SH603906
# 正在初始化:  SH600598
# 正在初始化:  SH601007
# 正在初始化:  SH600988
# 正在初始化:  SH601519
# 正在初始化:  SH600218
# 正在初始化:  SH600331
# 正在初始化:  SH603538
# 正在初始化:  SH600143
# 正在初始化:  SH600811
# 正在初始化:  SH600862
# 正在初始化:  SH600130
# 正在初始化:  SH600516
# 正在初始化:  SH600805
# 正在初始化:  SH600699
# 正在初始化:  SH601238
# 正在初始化:  SH603936
# 正在初始化:  SH603766
# 正在初始化:  SH600150
# 正在初始化:  SH600422
# 正在初始化:  SH603806
# 正在初始化:  SH600732
# 正在初始化:  SH600186
# 正在初始化:  SH600587
# 正在初始化:  SH603986
# 正在初始化:  SH603169
# 正在初始化:  SH600110
# 正在初始化:  SH601388
# 正在初始化:  SH601702
# 正在初始化:  SH600490
# 正在初始化:  SH600160
# 正在初始化:  SH600370
# 正在初始化:  SH600405
# 正在初始化:  SH600609
# 正在初始化:  SH600210
# 正在初始化:  SH600267
# 正在初始化:  SH601700
# 正在初始化:  SH600192
# 正在初始化:  SH600435
# 正在初始化:  SH600969
# 正在初始化:  SH600072
# 正在初始化:  SH603166
# 正在初始化:  SH600477
# 正在初始化:  SH600470
# 正在初始化:  SH601236
# 正在初始化:  SH600759
# 正在初始化:  SH600497
# 正在初始化:  SH600006
# 正在初始化:  SH600618
# 正在初始化:  SH600662
# 正在初始化:  SH600903
# 正在初始化:  SH603501
# 正在初始化:  SH600586
# 正在初始化:  SH600458
# 正在初始化:  SH600237
# 正在初始化:  SH603227
# 正在初始化:  SH603659
# 正在初始化:  SH600362
# 正在初始化:  SH601677
# 正在初始化:  SH600108
# 正在初始化:  SH600101
# 正在初始化:  SH600746
# 正在初始化:  SH688660
# 正在初始化:  SH601218
# 正在初始化:  SH600116
# 正在初始化:  SH603803
# 正在初始化:  SH603335
# 正在初始化:  SH601606
# 正在初始化:  SH601137
# 正在初始化:  SH600480
# 正在初始化:  SH603678
# 正在初始化:  SH603027
# 正在初始化:  SH600330
# 正在初始化:  SH600960
# 正在初始化:  SH600624
# 正在初始化:  SH600081
# 正在初始化:  SH600513
# 正在初始化:  SH600156
# 正在初始化:  SH600730
# 正在初始化:  SH600121
# 正在初始化:  SH600386
# 正在初始化:  SH600085
# 正在初始化:  SH600268
# 正在初始化:  SH600354
# 正在初始化:  SH601579
# 正在初始化:  SH600197
# 正在初始化:  SH600989
# 正在初始化:  SH600884
# 正在初始化:  SH600233
# 正在初始化:  SH601126
# 正在初始化:  SH600491
# 正在初始化:  SH601969
# 正在初始化:  SH603815
# 正在初始化:  SH600521
# 正在初始化:  SH600202
# 正在初始化:  SH600409
# 正在初始化:  SH601233
# 正在初始化:  SH600371
# 正在初始化:  SH600418
# 正在初始化:  SH601311
# 正在初始化:  SH600213
# 正在初始化:  SH600328
# 正在初始化:  SH601020
# 正在初始化:  SH600078
# 正在初始化:  SH601279
# 正在初始化:  SH600098
# 正在初始化:  SH603128
# 正在初始化:  SH600469
# 正在初始化:  SH600711
# 正在初始化:  SH600866
# 正在初始化:  SH600479
# 正在初始化:  SH600893
# 正在初始化:  SH601966
# 正在初始化:  SH600495
# 正在初始化:  SH600765
# 正在初始化:  SH603018
# 正在初始化:  SH688303
# 正在初始化:  SH600375
# 正在初始化:  SH600844
# 正在初始化:  SH600596
# 正在初始化:  SH600220
# 正在初始化:  SH600975
# 正在初始化:  SH600551
# 正在初始化:  SH601777
# 正在初始化:  SH600259
# 正在初始化:  SH600616
# Starting Portfolio Value: 1000000.00
#
# 获取最新交易日期...
# 当前获取的A股日期是： 20220622
#
# 获取上一个交易日...
# 当前获取的A股日期是： 20220621
#
# 策略初始化...
# 策略初始化: 99%:  ▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋ ▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋ ▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋ ▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋ ▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋ ▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋ ▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋2021-01-04, Buy SZ300479 Created 14.20
# 2021-01-04, Buy SZ300024 Created 12.43
# 2021-01-04, Buy SZ300293 Created 17.17
# 2021-01-04, Buy SZ300891 Created 18.55
# 2021-01-04, Buy SZ300585 Created 13.90
# 2021-01-04, Buy SZ300657 Created 13.61
# 2021-01-04, Buy SZ300400 Created 12.60
# 2021-01-04, Buy SZ002482 Created 3.08
# 2021-01-04, Buy SZ002031 Created 2.01
# 2021-01-04, Buy SZ000068 Created 3.18
    cumulative = (pnl + 1).cumprod()

    # 计算回撤序列
    max_return = cumulative.cummax()

    drawdown = (cumulative - max_return) / max_return

    # 按年统计收益指标
    perf_stats_year = (
        (pnl)
        .groupby(pnl.index.to_period("y"))
        .apply(lambda data: pf.timeseries.perf_stats(data))
        .unstack()
    )

    # 统计所有时间段的收益指标
    perf_stats_all = pf.timeseries.perf_stats((pnl)).to_frame(name="all")

    perf_stats = pd.concat([perf_stats_year, perf_stats_all.T], axis=0)

    perf_stats_ = round(perf_stats, 4).reset_index()


    # 绘制图形

    plt.rcParams["axes.unicode_minus"] = False  # 用来正常显示负号

    # 导入设置坐标轴的模块
    plt.style.use("seaborn")
    plt.style.use('dark_background')

    fig, (ax0, ax1) = plt.subplots(
        2, 1, gridspec_kw={"height_ratios": [1.5, 4]}, figsize=(20, 8)
    )

    cols_names = [
        "date",
        "Annual\nreturn",
        "Cumulative\nreturns",
        "Annual\nvolatility",
        "Sharpe\nratio",
        "Calmar\nratio",
        "Stability",
        "Max\ndrawdown",
        "Omega\nratio",
        "Sortino\nratio",
        "Skew",
        "Kurtosis",
        "Tail\nratio",
        "Daily value\nat risk",
    ]


    # 绘制表格
    ax0.set_axis_off()
    # 除去坐标轴
    table = ax0.table(
        cellText=perf_stats_.values,
        bbox=(0, 0, 1, 1),
        # 设置表格位置， (x0, y0, width, height)
        rowLoc="right",
        # 行标题居中
        cellLoc="right",
        colLabels=cols_names,
        # 设置列标题
        colLoc="right",
        # 列标题居中
        edges="open",  # 不显示表格边框
    )

    table.set_fontsize(13)


    # 绘制累计收益曲线
    ax2 = ax1.twinx()

    ax1.yaxis.set_ticks_position("right")
    # 将回撤曲线的 y 轴移至右侧
    ax2.yaxis.set_ticks_position("left")
    # 将累计收益曲线的 y 轴移至左侧
    # 绘制回撤曲线
    drawdown.plot.area(
        ax=ax1, label="drawdown (right)", rot=0, alpha=0.3, fontsize=13, grid=False
    )

    # 绘制累计收益曲线
    (cumulative).plot(
        ax=ax2,
        color="#F1C40F",
        lw=3.0,
        label="cumret (left)",
        rot=0,
        fontsize=13,
        grid=False,
    )

    # 不然 x 轴留有空白
    ax2.set_xbound(lower=cumulative.index.min(), upper=cumulative.index.max())

    # 主轴定位器：每 5 个月显示一个日期：根据具体天数来做排版
    ax2.xaxis.set_major_locator(ticker.MultipleLocator(100))

    # 同时绘制双轴的图例
    h1, l1 = ax1.get_legend_handles_labels()

    h2, l2 = ax2.get_legend_handles_labels()

    plt.legend(h1 + h2, l1 + l2, fontsize=12, loc="upper left", ncol=1)


    fig.tight_layout()
    # 规整排版
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_13230/3057165194.py in <module>
#       1 # 提取收益序列
# ----> 2 pnl = pd.Series(result[0].analyzers._TimeReturn.get_analysis())
#       3
#       4 # 计算累计收益
#       5 cumulative = (pnl + 1).cumprod()
#
# NameError: name 'result' is not defined

# %%
pf.create_full_tear_sheet(returns=ret,benchmark_rets=benchmark_ret,live_start_date=date)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_13217/2302244143.py in <module>
# ----> 1 pf.create_full_tear_sheet(returns=ret,benchmark_rets=benchmark_ret,live_start_date=date)
#
# NameError: name 'ret' is not defined
